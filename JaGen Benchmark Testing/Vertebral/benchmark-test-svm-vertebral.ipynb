# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
from cuml.svm import SVC, SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import seaborn as sns
from sklearn.tree import plot_tree
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")


from sklearn import set_config 

set_config(display="diagram")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
#Genetic
df = pd.read_csv("/kaggle/input/benchmarkjagen/Vertebral/Results_Genetic.csv")
df.head(11)
indexs_Genetic = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Genetic.append(np.array(numbers))
        
#ISCA        
df = pd.read_csv("/kaggle/input/benchmarkjagen/Vertebral/Results_ISCA.csv")
df.head(11)
indexs_ISCA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISCA.append(np.array(numbers))

#ISSA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Vertebral/Results_ISSA.csv")
df.head(11)
indexs_ISSA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISSA.append(np.array(numbers))
        
#JA_GA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Vertebral/Results_JA+GA.csv")
df.head(11)
indexs_JA_GA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_JA_GA.append(np.array(numbers))

#Jaya
df = pd.read_csv("/kaggle/input/benchmarkjagen/Vertebral/Results_Jaya.csv")
df.head(11)
indexs_Jaya = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Jaya.append(np.array(numbers))

#MGFPA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Vertebral/Results_MGFPA.csv")
df.head(11)
indexs_MGFPA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_MGFPA.append(np.array(numbers))

#PSO
df = pd.read_csv("/kaggle/input/benchmarkjagen/Vertebral/Results_PSO.csv")
df.head(11)
indexs_PSO = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_PSO.append(np.array(numbers))

# %%
#Original
features_test_Vertebral = np.load('/kaggle/input/benchmarkjagen/Vertebral/xtest.npy')
y_test = np.load("/kaggle/input/benchmarkjagen/Vertebral/ytest.npy")
features_train_Vertebral = np.load('/kaggle/input/benchmarkjagen/Vertebral/xtrain.npy')
y_train = np.load("/kaggle/input/benchmarkjagen/Vertebral/ytrain.npy")
#JA + GA (Jaya + Genetic)
featuresIndex_Vertebral_JA_GA_100iter_run1 = indexs_JA_GA[0]
featuresIndex_Vertebral_JA_GA_100iter_run2 = indexs_JA_GA[1]
featuresIndex_Vertebral_JA_GA_100iter_run3 = indexs_JA_GA[2]
featuresIndex_Vertebral_JA_GA_100iter_run4 = indexs_JA_GA[3]
featuresIndex_Vertebral_JA_GA_100iter_run5 = indexs_JA_GA[4]
featuresIndex_Vertebral_JA_GA_100iter_run6 = indexs_JA_GA[5]
featuresIndex_Vertebral_JA_GA_100iter_run7 = indexs_JA_GA[6]
featuresIndex_Vertebral_JA_GA_100iter_run8 = indexs_JA_GA[7]
featuresIndex_Vertebral_JA_GA_100iter_run9 = indexs_JA_GA[8]
featuresIndex_Vertebral_JA_GA_100iter_run10 = indexs_JA_GA[9]

featuresIndex_Vertebral_JA_GA_380iter_run1 = indexs_JA_GA[0]
featuresIndex_Vertebral_JA_GA_380iter_run2 = indexs_JA_GA[1]
featuresIndex_Vertebral_JA_GA_380iter_run3 = indexs_JA_GA[2]
featuresIndex_Vertebral_JA_GA_380iter_run4 = indexs_JA_GA[3]
featuresIndex_Vertebral_JA_GA_380iter_run5 = indexs_JA_GA[4]
featuresIndex_Vertebral_JA_GA_380iter_run6 = indexs_JA_GA[5]
featuresIndex_Vertebral_JA_GA_380iter_run7 = indexs_JA_GA[6]
featuresIndex_Vertebral_JA_GA_380iter_run8 = indexs_JA_GA[7]
featuresIndex_Vertebral_JA_GA_380iter_run9 = indexs_JA_GA[8]
featuresIndex_Vertebral_JA_GA_380iter_run10 = indexs_JA_GA[9]

#ISSA
featuresIndex_Vertebral_ISSA_100iter_run1 = indexs_ISSA[0]
featuresIndex_Vertebral_ISSA_100iter_run2 = indexs_ISSA[1]
featuresIndex_Vertebral_ISSA_100iter_run3 = indexs_ISSA[2]
featuresIndex_Vertebral_ISSA_100iter_run4 = indexs_ISSA[3]
featuresIndex_Vertebral_ISSA_100iter_run5 = indexs_ISSA[4]
featuresIndex_Vertebral_ISSA_100iter_run6 = indexs_ISSA[5]
featuresIndex_Vertebral_ISSA_100iter_run7 = indexs_ISSA[6]
featuresIndex_Vertebral_ISSA_100iter_run8 = indexs_ISSA[7]
featuresIndex_Vertebral_ISSA_100iter_run9 = indexs_ISSA[8]
featuresIndex_Vertebral_ISSA_100iter_run10 = indexs_ISSA[9]

featuresIndex_Vertebral_ISSA_380iter_run1 = indexs_ISSA[0]
featuresIndex_Vertebral_ISSA_380iter_run2 = indexs_ISSA[1]
featuresIndex_Vertebral_ISSA_380iter_run3 = indexs_ISSA[2]
featuresIndex_Vertebral_ISSA_380iter_run4 = indexs_ISSA[3]
featuresIndex_Vertebral_ISSA_380iter_run5 = indexs_ISSA[4]
featuresIndex_Vertebral_ISSA_380iter_run6 = indexs_ISSA[5]
featuresIndex_Vertebral_ISSA_380iter_run7 = indexs_ISSA[6]
featuresIndex_Vertebral_ISSA_380iter_run8 = indexs_ISSA[7]
featuresIndex_Vertebral_ISSA_380iter_run9 = indexs_ISSA[8]
featuresIndex_Vertebral_ISSA_380iter_run10 = indexs_ISSA[9]

#Jaya
featuresIndex_Vertebral_Jaya_100iter_run1 = indexs_Jaya[0]
featuresIndex_Vertebral_Jaya_100iter_run2 = indexs_Jaya[1]
featuresIndex_Vertebral_Jaya_100iter_run3 = indexs_Jaya[2]
featuresIndex_Vertebral_Jaya_100iter_run4 = indexs_Jaya[3]
featuresIndex_Vertebral_Jaya_100iter_run5 = indexs_Jaya[4]
featuresIndex_Vertebral_Jaya_100iter_run6 = indexs_Jaya[5]
featuresIndex_Vertebral_Jaya_100iter_run7 = indexs_Jaya[6]
featuresIndex_Vertebral_Jaya_100iter_run8 = indexs_Jaya[7]
featuresIndex_Vertebral_Jaya_100iter_run9 = indexs_Jaya[8]
featuresIndex_Vertebral_Jaya_100iter_run10 = indexs_Jaya[9]

featuresIndex_Vertebral_Jaya_380iter_run1 = indexs_Jaya[0]
featuresIndex_Vertebral_Jaya_380iter_run2 = indexs_Jaya[1]
featuresIndex_Vertebral_Jaya_380iter_run3 = indexs_Jaya[2]
featuresIndex_Vertebral_Jaya_380iter_run4 = indexs_Jaya[3]
featuresIndex_Vertebral_Jaya_380iter_run5 = indexs_Jaya[4]
featuresIndex_Vertebral_Jaya_380iter_run6 = indexs_Jaya[5]
featuresIndex_Vertebral_Jaya_380iter_run7 = indexs_Jaya[6]
featuresIndex_Vertebral_Jaya_380iter_run8 = indexs_Jaya[7]
featuresIndex_Vertebral_Jaya_380iter_run9 = indexs_Jaya[8]
featuresIndex_Vertebral_Jaya_380iter_run10 = indexs_Jaya[9]

#PSO
featuresIndex_Vertebral_PSO_100iter_run1 = indexs_PSO[0]
featuresIndex_Vertebral_PSO_100iter_run2 = indexs_PSO[1]
featuresIndex_Vertebral_PSO_100iter_run3 = indexs_PSO[2]
featuresIndex_Vertebral_PSO_100iter_run4 = indexs_PSO[3]
featuresIndex_Vertebral_PSO_100iter_run5 = indexs_PSO[4]
featuresIndex_Vertebral_PSO_100iter_run6 = indexs_PSO[5]
featuresIndex_Vertebral_PSO_100iter_run7 = indexs_PSO[6]
featuresIndex_Vertebral_PSO_100iter_run8 = indexs_PSO[7]
featuresIndex_Vertebral_PSO_100iter_run9 = indexs_PSO[8]
featuresIndex_Vertebral_PSO_100iter_run10 = indexs_PSO[9]

featuresIndex_Vertebral_PSO_380iter_run1 = indexs_PSO[0]
featuresIndex_Vertebral_PSO_380iter_run2 = indexs_PSO[1]
featuresIndex_Vertebral_PSO_380iter_run3 = indexs_PSO[2]
featuresIndex_Vertebral_PSO_380iter_run4 = indexs_PSO[3]
featuresIndex_Vertebral_PSO_380iter_run5 = indexs_PSO[4]
featuresIndex_Vertebral_PSO_380iter_run6 = indexs_PSO[5]
featuresIndex_Vertebral_PSO_380iter_run7 = indexs_PSO[6]
featuresIndex_Vertebral_PSO_380iter_run8 = indexs_PSO[7]
featuresIndex_Vertebral_PSO_380iter_run9 = indexs_PSO[8]
featuresIndex_Vertebral_PSO_380iter_run10 = indexs_PSO[9]

#MGFPA
featuresIndex_Vertebral_MGFPA_100iter_run1 = indexs_MGFPA[0]
featuresIndex_Vertebral_MGFPA_100iter_run2 = indexs_MGFPA[1]
featuresIndex_Vertebral_MGFPA_100iter_run3 = indexs_MGFPA[2]
featuresIndex_Vertebral_MGFPA_100iter_run4 = indexs_MGFPA[3]
featuresIndex_Vertebral_MGFPA_100iter_run5 = indexs_MGFPA[4]
featuresIndex_Vertebral_MGFPA_100iter_run6 = indexs_MGFPA[5]
featuresIndex_Vertebral_MGFPA_100iter_run7 = indexs_MGFPA[6]
featuresIndex_Vertebral_MGFPA_100iter_run8 = indexs_MGFPA[7]
featuresIndex_Vertebral_MGFPA_100iter_run9 = indexs_MGFPA[8]
featuresIndex_Vertebral_MGFPA_100iter_run10 = indexs_MGFPA[9]

featuresIndex_Vertebral_MGFPA_380iter_run1 = indexs_MGFPA[0]
featuresIndex_Vertebral_MGFPA_380iter_run2 = indexs_MGFPA[1]
featuresIndex_Vertebral_MGFPA_380iter_run3 = indexs_MGFPA[2]
featuresIndex_Vertebral_MGFPA_380iter_run4 = indexs_MGFPA[3]
featuresIndex_Vertebral_MGFPA_380iter_run5 = indexs_MGFPA[4]
featuresIndex_Vertebral_MGFPA_380iter_run6 = indexs_MGFPA[5]
featuresIndex_Vertebral_MGFPA_380iter_run7 = indexs_MGFPA[6]
featuresIndex_Vertebral_MGFPA_380iter_run8 = indexs_MGFPA[7]
featuresIndex_Vertebral_MGFPA_380iter_run9 = indexs_MGFPA[8]
featuresIndex_Vertebral_MGFPA_380iter_run10 = indexs_MGFPA[9]

#Genetic
featuresIndex_Vertebral_Genetic_100iter_run1 = indexs_Genetic[0]
featuresIndex_Vertebral_Genetic_100iter_run2 = indexs_Genetic[1]
featuresIndex_Vertebral_Genetic_100iter_run3 = indexs_Genetic[2]
featuresIndex_Vertebral_Genetic_100iter_run4 = indexs_Genetic[3]
featuresIndex_Vertebral_Genetic_100iter_run5 = indexs_Genetic[4]
featuresIndex_Vertebral_Genetic_100iter_run6 = indexs_Genetic[5]
featuresIndex_Vertebral_Genetic_100iter_run7 = indexs_Genetic[6]
featuresIndex_Vertebral_Genetic_100iter_run8 = indexs_Genetic[7]
featuresIndex_Vertebral_Genetic_100iter_run9 = indexs_Genetic[8]
featuresIndex_Vertebral_Genetic_100iter_run10 = indexs_Genetic[9]

featuresIndex_Vertebral_Genetic_380iter_run1 = indexs_Genetic[0]
featuresIndex_Vertebral_Genetic_380iter_run2 = indexs_Genetic[1]
featuresIndex_Vertebral_Genetic_380iter_run3 = indexs_Genetic[2]
featuresIndex_Vertebral_Genetic_380iter_run4 = indexs_Genetic[3]
featuresIndex_Vertebral_Genetic_380iter_run5 = indexs_Genetic[4]
featuresIndex_Vertebral_Genetic_380iter_run6 = indexs_Genetic[5]
featuresIndex_Vertebral_Genetic_380iter_run7 = indexs_Genetic[6]
featuresIndex_Vertebral_Genetic_380iter_run8 = indexs_Genetic[7]
featuresIndex_Vertebral_Genetic_380iter_run9 = indexs_Genetic[8]
featuresIndex_Vertebral_Genetic_380iter_run10 = indexs_Genetic[9]

#ISCA
featuresIndex_Vertebral_ISCA_100iter_run1 = indexs_ISCA[0]
featuresIndex_Vertebral_ISCA_100iter_run2 = indexs_ISCA[1]
featuresIndex_Vertebral_ISCA_100iter_run3 = indexs_ISCA[2]
featuresIndex_Vertebral_ISCA_100iter_run4 = indexs_ISCA[3]
featuresIndex_Vertebral_ISCA_100iter_run5 = indexs_ISCA[4]
featuresIndex_Vertebral_ISCA_100iter_run6 = indexs_ISCA[5]
featuresIndex_Vertebral_ISCA_100iter_run7 = indexs_ISCA[6]
featuresIndex_Vertebral_ISCA_100iter_run8 = indexs_ISCA[7]
featuresIndex_Vertebral_ISCA_100iter_run9 = indexs_ISCA[8]
featuresIndex_Vertebral_ISCA_100iter_run10 = indexs_ISCA[9]

featuresIndex_Vertebral_ISCA_380iter_run1 = indexs_ISCA[0]
featuresIndex_Vertebral_ISCA_380iter_run2 = indexs_ISCA[1]
featuresIndex_Vertebral_ISCA_380iter_run3 = indexs_ISCA[2]
featuresIndex_Vertebral_ISCA_380iter_run4 = indexs_ISCA[3]
featuresIndex_Vertebral_ISCA_380iter_run5 = indexs_ISCA[4]
featuresIndex_Vertebral_ISCA_380iter_run6 = indexs_ISCA[5]
featuresIndex_Vertebral_ISCA_380iter_run7 = indexs_ISCA[6]
featuresIndex_Vertebral_ISCA_380iter_run8 = indexs_ISCA[7]
featuresIndex_Vertebral_ISCA_380iter_run9 = indexs_ISCA[8]
featuresIndex_Vertebral_ISCA_380iter_run10 = indexs_ISCA[9]

# %% [markdown]
# # 100 Iteration (10 Individual Runs)

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_JA_GA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Vertebral_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Vertebral_100iter.to_csv("./cv10_results_JA_GA_Vertebral_100iter.csv")
cv10_results_JA_GA_Vertebral_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_ISSA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISSA_Vertebral_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Vertebral_100iter.to_csv("./cv10_results_ISSA_Vertebral_100iter.csv")
cv10_results_ISSA_Vertebral_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_ISCA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISCA_Vertebral_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Vertebral_100iter.to_csv("./cv10_results_ISCA_Vertebral_100iter.csv")
cv10_results_ISCA_Vertebral_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_Genetic_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Vertebral_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Vertebral_100iter.to_csv("./cv10_results_Genetic_Vertebral_100iter.csv")
cv10_results_Genetic_Vertebral_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8387096774193549  Precision:  0.7863247863247863  Recall:  0.7444444444444445  F1-Score:  0.7423510466988729
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8387096774193549  Precision:  0.7863247863247863  Recall:  0.7444444444444445  F1-Score:  0.7423510466988729
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8387096774193549  Precision:  0.7863247863247863  Recall:  0.7444444444444445  F1-Score:  0.7423510466988729
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8387096774193549  Precision:  0.7863247863247863  Recall:  0.7444444444444445  F1-Score:  0.7423510466988729
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8387096774193549  Precision:  0.7777777777777778  Recall:  0.7777777777777778  F1-Score:  0.7777777777777778
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_Jaya_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Vertebral_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Vertebral_100iter.to_csv("./cv10_results_Jaya_Vertebral_100iter.csv")
cv10_results_Jaya_Vertebral_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8548387096774194  Precision:  0.8130434782608695  Recall:  0.7999999999999999  F1-Score:  0.8033707194132894
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_PSO_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Vertebral_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Vertebral_100iter.to_csv("./cv10_results_PSO_Vertebral_100iter.csv")
cv10_results_PSO_Vertebral_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7741935483870968  Precision:  0.6994949494949495  Recall:  0.7000000000000001  F1-Score:  0.6988232074438971
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_MGFPA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Vertebral_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Vertebral_100iter.to_csv("./cv10_results_MGFPA_Vertebral_100iter.csv")
cv10_results_MGFPA_Vertebral_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# # 380 Iteration

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_JA_GA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")


av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Vertebral_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Vertebral_380iter.to_csv("./cv10_results_JA_GA_Vertebral_380iter.csv")
cv10_results_JA_GA_Vertebral_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8709677419354839  Precision:  0.8242424242424242  Recall:  0.8111111111111112  F1-Score:  0.8152958152958153
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# #### ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_ISSA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISSA_Vertebral_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Vertebral_380iter.to_csv("./cv10_results_ISSA_Vertebral_380iter.csv")
cv10_results_ISSA_Vertebral_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_ISCA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISCA_Vertebral_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Vertebral_380iter.to_csv("./cv10_results_ISCA_Vertebral_380iter.csv")
cv10_results_ISCA_Vertebral_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8870967741935484  Precision:  0.8534621578099838  Recall:  0.8277777777777778  F1-Score:  0.834625322997416
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8870967741935484  Precision:  0.8534621578099838  Recall:  0.8277777777777778  F1-Score:  0.834625322997416
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8870967741935484  Precision:  0.8534621578099838  Recall:  0.8277777777777778  F1-Score:  0.834625322997416
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8870967741935484  Precision:  0.8534621578099838  Recall:  0.8277777777777778  F1-Score:  0.834625322997416
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8870967741935484  Precision:  0.8534621578099838  Recall:  0.8277777777777778  F1-Score:  0.834625322997416
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_Genetic_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Vertebral_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Vertebral_380iter.to_csv("./cv10_results_Genetic_Vertebral_380iter.csv")
cv10_results_Genetic_Vertebral_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7741935483870968  Precision:  0.6994949494949495  Recall:  0.7000000000000001  F1-Score:  0.6988232074438971
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_Jaya_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Vertebral_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Vertebral_380iter.to_csv("./cv10_results_Jaya_Vertebral_380iter.csv")
cv10_results_Jaya_Vertebral_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8225806451612904  Precision:  0.7933333333333333  Recall:  0.7777777777777778  F1-Score:  0.7797625376572747
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8225806451612904  Precision:  0.7683333333333334  Recall:  0.7444444444444445  F1-Score:  0.7462021343377275
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_PSO_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Vertebral_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Vertebral_380iter.to_csv("./cv10_results_PSO_Vertebral_380iter.csv")
cv10_results_PSO_Vertebral_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7741935483870968  Precision:  0.6994949494949495  Recall:  0.7000000000000001  F1-Score:  0.6988232074438971
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8064516129032258  Precision:  0.7451851851851852  Recall:  0.7333333333333334  F1-Score:  0.7324210910417808
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Vertebral_MGFPA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Vertebral[:, var_value_indexes]
    xtest = features_test_Vertebral[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Vertebral_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Vertebral_380iter.to_csv("./cv10_results_MGFPA_Vertebral_380iter.csv")
cv10_results_MGFPA_Vertebral_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8548387096774194  Precision:  0.8130434782608695  Recall:  0.7999999999999999  F1-Score:  0.8033707194132894
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8548387096774194  Precision:  0.8130434782608695  Recall:  0.7999999999999999  F1-Score:  0.8033707194132894
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8548387096774194  Precision:  0.8130434782608695  Recall:  0.7999999999999999  F1-Score:  0.8033707194132894
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8548387096774194  Precision:  0.8130434782608695  Recall:  0.7999999999999999  F1-Score:  0.8033707194132894
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8548387096774194  Precision:  0.8130434782608695  Recall:  0.7999999999999999  F1-Score:  0.8033707194132894
# ---------------------------------------------------------
# Run:  6
# ...
