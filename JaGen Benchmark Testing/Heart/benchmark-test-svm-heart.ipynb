# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
from cuml.svm import SVC, SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import seaborn as sns
from sklearn.tree import plot_tree
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")


from sklearn import set_config 

set_config(display="diagram")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
#Genetic
df = pd.read_csv("/kaggle/input/benchmarkjagen/Heart-Statlog/Results_Genetic.csv")
df.head(11)
indexs_Genetic = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Genetic.append(np.array(numbers))
        
#ISCA        
df = pd.read_csv("/kaggle/input/benchmarkjagen/Heart-Statlog/Results_ISCA.csv")
df.head(11)
indexs_ISCA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISCA.append(np.array(numbers))

#ISSA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Heart-Statlog/Results_ISSA.csv")
df.head(11)
indexs_ISSA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISSA.append(np.array(numbers))
        
#JA_GA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Heart-Statlog/Results_JA+GA.csv")
df.head(11)
indexs_JA_GA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_JA_GA.append(np.array(numbers))

#Jaya
df = pd.read_csv("/kaggle/input/benchmarkjagen/Heart-Statlog/Results_Jaya.csv")
df.head(11)
indexs_Jaya = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Jaya.append(np.array(numbers))

#MGFPA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Heart-Statlog/Results_MGFPA.csv")
df.head(11)
indexs_MGFPA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_MGFPA.append(np.array(numbers))

#PSO
df = pd.read_csv("/kaggle/input/benchmarkjagen/Heart-Statlog/Results_PSO.csv")
df.head(11)
indexs_PSO = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_PSO.append(np.array(numbers))

# %%
#Original
features_test_Heart = np.load('/kaggle/input/benchmarkjagen/Heart-Statlog/xtest.npy')
y_test = np.load("/kaggle/input/benchmarkjagen/Heart-Statlog/ytest.npy")
features_train_Heart = np.load('/kaggle/input/benchmarkjagen/Heart-Statlog/xtrain.npy')
y_train = np.load("/kaggle/input/benchmarkjagen/Heart-Statlog/ytrain.npy")
#JA + GA (Jaya + Genetic)
featuresIndex_Heart_JA_GA_100iter_run1 = indexs_JA_GA[0]
featuresIndex_Heart_JA_GA_100iter_run2 = indexs_JA_GA[1]
featuresIndex_Heart_JA_GA_100iter_run3 = indexs_JA_GA[2]
featuresIndex_Heart_JA_GA_100iter_run4 = indexs_JA_GA[3]
featuresIndex_Heart_JA_GA_100iter_run5 = indexs_JA_GA[4]
featuresIndex_Heart_JA_GA_100iter_run6 = indexs_JA_GA[5]
featuresIndex_Heart_JA_GA_100iter_run7 = indexs_JA_GA[6]
featuresIndex_Heart_JA_GA_100iter_run8 = indexs_JA_GA[7]
featuresIndex_Heart_JA_GA_100iter_run9 = indexs_JA_GA[8]
featuresIndex_Heart_JA_GA_100iter_run10 = indexs_JA_GA[9]

featuresIndex_Heart_JA_GA_380iter_run1 = indexs_JA_GA[0]
featuresIndex_Heart_JA_GA_380iter_run2 = indexs_JA_GA[1]
featuresIndex_Heart_JA_GA_380iter_run3 = indexs_JA_GA[2]
featuresIndex_Heart_JA_GA_380iter_run4 = indexs_JA_GA[3]
featuresIndex_Heart_JA_GA_380iter_run5 = indexs_JA_GA[4]
featuresIndex_Heart_JA_GA_380iter_run6 = indexs_JA_GA[5]
featuresIndex_Heart_JA_GA_380iter_run7 = indexs_JA_GA[6]
featuresIndex_Heart_JA_GA_380iter_run8 = indexs_JA_GA[7]
featuresIndex_Heart_JA_GA_380iter_run9 = indexs_JA_GA[8]
featuresIndex_Heart_JA_GA_380iter_run10 = indexs_JA_GA[9]

#ISSA
featuresIndex_Heart_ISSA_100iter_run1 = indexs_ISSA[0]
featuresIndex_Heart_ISSA_100iter_run2 = indexs_ISSA[1]
featuresIndex_Heart_ISSA_100iter_run3 = indexs_ISSA[2]
featuresIndex_Heart_ISSA_100iter_run4 = indexs_ISSA[3]
featuresIndex_Heart_ISSA_100iter_run5 = indexs_ISSA[4]
featuresIndex_Heart_ISSA_100iter_run6 = indexs_ISSA[5]
featuresIndex_Heart_ISSA_100iter_run7 = indexs_ISSA[6]
featuresIndex_Heart_ISSA_100iter_run8 = indexs_ISSA[7]
featuresIndex_Heart_ISSA_100iter_run9 = indexs_ISSA[8]
featuresIndex_Heart_ISSA_100iter_run10 = indexs_ISSA[9]

featuresIndex_Heart_ISSA_380iter_run1 = indexs_ISSA[0]
featuresIndex_Heart_ISSA_380iter_run2 = indexs_ISSA[1]
featuresIndex_Heart_ISSA_380iter_run3 = indexs_ISSA[2]
featuresIndex_Heart_ISSA_380iter_run4 = indexs_ISSA[3]
featuresIndex_Heart_ISSA_380iter_run5 = indexs_ISSA[4]
featuresIndex_Heart_ISSA_380iter_run6 = indexs_ISSA[5]
featuresIndex_Heart_ISSA_380iter_run7 = indexs_ISSA[6]
featuresIndex_Heart_ISSA_380iter_run8 = indexs_ISSA[7]
featuresIndex_Heart_ISSA_380iter_run9 = indexs_ISSA[8]
featuresIndex_Heart_ISSA_380iter_run10 = indexs_ISSA[9]

#Jaya
featuresIndex_Heart_Jaya_100iter_run1 = indexs_Jaya[0]
featuresIndex_Heart_Jaya_100iter_run2 = indexs_Jaya[1]
featuresIndex_Heart_Jaya_100iter_run3 = indexs_Jaya[2]
featuresIndex_Heart_Jaya_100iter_run4 = indexs_Jaya[3]
featuresIndex_Heart_Jaya_100iter_run5 = indexs_Jaya[4]
featuresIndex_Heart_Jaya_100iter_run6 = indexs_Jaya[5]
featuresIndex_Heart_Jaya_100iter_run7 = indexs_Jaya[6]
featuresIndex_Heart_Jaya_100iter_run8 = indexs_Jaya[7]
featuresIndex_Heart_Jaya_100iter_run9 = indexs_Jaya[8]
featuresIndex_Heart_Jaya_100iter_run10 = indexs_Jaya[9]

featuresIndex_Heart_Jaya_380iter_run1 = indexs_Jaya[0]
featuresIndex_Heart_Jaya_380iter_run2 = indexs_Jaya[1]
featuresIndex_Heart_Jaya_380iter_run3 = indexs_Jaya[2]
featuresIndex_Heart_Jaya_380iter_run4 = indexs_Jaya[3]
featuresIndex_Heart_Jaya_380iter_run5 = indexs_Jaya[4]
featuresIndex_Heart_Jaya_380iter_run6 = indexs_Jaya[5]
featuresIndex_Heart_Jaya_380iter_run7 = indexs_Jaya[6]
featuresIndex_Heart_Jaya_380iter_run8 = indexs_Jaya[7]
featuresIndex_Heart_Jaya_380iter_run9 = indexs_Jaya[8]
featuresIndex_Heart_Jaya_380iter_run10 = indexs_Jaya[9]

#PSO
featuresIndex_Heart_PSO_100iter_run1 = indexs_PSO[0]
featuresIndex_Heart_PSO_100iter_run2 = indexs_PSO[1]
featuresIndex_Heart_PSO_100iter_run3 = indexs_PSO[2]
featuresIndex_Heart_PSO_100iter_run4 = indexs_PSO[3]
featuresIndex_Heart_PSO_100iter_run5 = indexs_PSO[4]
featuresIndex_Heart_PSO_100iter_run6 = indexs_PSO[5]
featuresIndex_Heart_PSO_100iter_run7 = indexs_PSO[6]
featuresIndex_Heart_PSO_100iter_run8 = indexs_PSO[7]
featuresIndex_Heart_PSO_100iter_run9 = indexs_PSO[8]
featuresIndex_Heart_PSO_100iter_run10 = indexs_PSO[9]

featuresIndex_Heart_PSO_380iter_run1 = indexs_PSO[0]
featuresIndex_Heart_PSO_380iter_run2 = indexs_PSO[1]
featuresIndex_Heart_PSO_380iter_run3 = indexs_PSO[2]
featuresIndex_Heart_PSO_380iter_run4 = indexs_PSO[3]
featuresIndex_Heart_PSO_380iter_run5 = indexs_PSO[4]
featuresIndex_Heart_PSO_380iter_run6 = indexs_PSO[5]
featuresIndex_Heart_PSO_380iter_run7 = indexs_PSO[6]
featuresIndex_Heart_PSO_380iter_run8 = indexs_PSO[7]
featuresIndex_Heart_PSO_380iter_run9 = indexs_PSO[8]
featuresIndex_Heart_PSO_380iter_run10 = indexs_PSO[9]

#MGFPA
featuresIndex_Heart_MGFPA_100iter_run1 = indexs_MGFPA[0]
featuresIndex_Heart_MGFPA_100iter_run2 = indexs_MGFPA[1]
featuresIndex_Heart_MGFPA_100iter_run3 = indexs_MGFPA[2]
featuresIndex_Heart_MGFPA_100iter_run4 = indexs_MGFPA[3]
featuresIndex_Heart_MGFPA_100iter_run5 = indexs_MGFPA[4]
featuresIndex_Heart_MGFPA_100iter_run6 = indexs_MGFPA[5]
featuresIndex_Heart_MGFPA_100iter_run7 = indexs_MGFPA[6]
featuresIndex_Heart_MGFPA_100iter_run8 = indexs_MGFPA[7]
featuresIndex_Heart_MGFPA_100iter_run9 = indexs_MGFPA[8]
featuresIndex_Heart_MGFPA_100iter_run10 = indexs_MGFPA[9]

featuresIndex_Heart_MGFPA_380iter_run1 = indexs_MGFPA[0]
featuresIndex_Heart_MGFPA_380iter_run2 = indexs_MGFPA[1]
featuresIndex_Heart_MGFPA_380iter_run3 = indexs_MGFPA[2]
featuresIndex_Heart_MGFPA_380iter_run4 = indexs_MGFPA[3]
featuresIndex_Heart_MGFPA_380iter_run5 = indexs_MGFPA[4]
featuresIndex_Heart_MGFPA_380iter_run6 = indexs_MGFPA[5]
featuresIndex_Heart_MGFPA_380iter_run7 = indexs_MGFPA[6]
featuresIndex_Heart_MGFPA_380iter_run8 = indexs_MGFPA[7]
featuresIndex_Heart_MGFPA_380iter_run9 = indexs_MGFPA[8]
featuresIndex_Heart_MGFPA_380iter_run10 = indexs_MGFPA[9]

#Genetic
featuresIndex_Heart_Genetic_100iter_run1 = indexs_Genetic[0]
featuresIndex_Heart_Genetic_100iter_run2 = indexs_Genetic[1]
featuresIndex_Heart_Genetic_100iter_run3 = indexs_Genetic[2]
featuresIndex_Heart_Genetic_100iter_run4 = indexs_Genetic[3]
featuresIndex_Heart_Genetic_100iter_run5 = indexs_Genetic[4]
featuresIndex_Heart_Genetic_100iter_run6 = indexs_Genetic[5]
featuresIndex_Heart_Genetic_100iter_run7 = indexs_Genetic[6]
featuresIndex_Heart_Genetic_100iter_run8 = indexs_Genetic[7]
featuresIndex_Heart_Genetic_100iter_run9 = indexs_Genetic[8]
featuresIndex_Heart_Genetic_100iter_run10 = indexs_Genetic[9]

featuresIndex_Heart_Genetic_380iter_run1 = indexs_Genetic[0]
featuresIndex_Heart_Genetic_380iter_run2 = indexs_Genetic[1]
featuresIndex_Heart_Genetic_380iter_run3 = indexs_Genetic[2]
featuresIndex_Heart_Genetic_380iter_run4 = indexs_Genetic[3]
featuresIndex_Heart_Genetic_380iter_run5 = indexs_Genetic[4]
featuresIndex_Heart_Genetic_380iter_run6 = indexs_Genetic[5]
featuresIndex_Heart_Genetic_380iter_run7 = indexs_Genetic[6]
featuresIndex_Heart_Genetic_380iter_run8 = indexs_Genetic[7]
featuresIndex_Heart_Genetic_380iter_run9 = indexs_Genetic[8]
featuresIndex_Heart_Genetic_380iter_run10 = indexs_Genetic[9]

#ISCA
featuresIndex_Heart_ISCA_100iter_run1 = indexs_ISCA[0]
featuresIndex_Heart_ISCA_100iter_run2 = indexs_ISCA[1]
featuresIndex_Heart_ISCA_100iter_run3 = indexs_ISCA[2]
featuresIndex_Heart_ISCA_100iter_run4 = indexs_ISCA[3]
featuresIndex_Heart_ISCA_100iter_run5 = indexs_ISCA[4]
featuresIndex_Heart_ISCA_100iter_run6 = indexs_ISCA[5]
featuresIndex_Heart_ISCA_100iter_run7 = indexs_ISCA[6]
featuresIndex_Heart_ISCA_100iter_run8 = indexs_ISCA[7]
featuresIndex_Heart_ISCA_100iter_run9 = indexs_ISCA[8]
featuresIndex_Heart_ISCA_100iter_run10 = indexs_ISCA[9]

featuresIndex_Heart_ISCA_380iter_run1 = indexs_ISCA[0]
featuresIndex_Heart_ISCA_380iter_run2 = indexs_ISCA[1]
featuresIndex_Heart_ISCA_380iter_run3 = indexs_ISCA[2]
featuresIndex_Heart_ISCA_380iter_run4 = indexs_ISCA[3]
featuresIndex_Heart_ISCA_380iter_run5 = indexs_ISCA[4]
featuresIndex_Heart_ISCA_380iter_run6 = indexs_ISCA[5]
featuresIndex_Heart_ISCA_380iter_run7 = indexs_ISCA[6]
featuresIndex_Heart_ISCA_380iter_run8 = indexs_ISCA[7]
featuresIndex_Heart_ISCA_380iter_run9 = indexs_ISCA[8]
featuresIndex_Heart_ISCA_380iter_run10 = indexs_ISCA[9]

# %% [markdown]
# # 100 Iteration (10 Individual Runs)

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_JA_GA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Heart_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Heart_100iter.to_csv("./cv10_results_JA_GA_Heart_100iter.csv")
cv10_results_JA_GA_Heart_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8888888888888888  Precision:  0.8875  Recall:  0.8875  F1-Score:  0.8875
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8703703703703703  Precision:  0.8703703703703703  Recall:  0.875  F1-Score:  0.869969040247678
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  6
#  Accuracy:  0.9074074074074074  Precision:  0.9055172413793103  Recall:  0.9083333333333333  F1-Score:  0.9066067104808024
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_ISSA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISSA_Heart_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Heart_100iter.to_csv("./cv10_results_ISSA_Heart_100iter.csv")
cv10_results_ISSA_Heart_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7407407407407407  Precision:  0.739010989010989  Recall:  0.7416666666666667  F1-Score:  0.7393103448275862
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8333333333333334  Precision:  0.8333333333333333  Recall:  0.8375  F1-Score:  0.8328173374613004
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7592592592592593  Precision:  0.7592592592592593  Recall:  0.7625  F1-Score:  0.758513931888545
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8148148148148148  Precision:  0.8153409090909092  Recall:  0.8083333333333333  F1-Score:  0.8106591865357644
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8888888888888888  Precision:  0.8875  Recall:  0.8875  F1-Score:  0.8875
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_ISCA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISCA_Heart_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Heart_100iter.to_csv("./cv10_results_ISCA_Heart_100iter.csv")
cv10_results_ISCA_Heart_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8333333333333334  Precision:  0.8333333333333333  Recall:  0.8375  F1-Score:  0.8328173374613004
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8333333333333334  Precision:  0.832398316970547  Recall:  0.8291666666666666  F1-Score:  0.8304848273456575
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8888888888888888  Precision:  0.8875  Recall:  0.8875  F1-Score:  0.8875
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7222222222222222  Precision:  0.7222222222222222  Recall:  0.725  F1-Score:  0.7213622291021671
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_Genetic_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Heart_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Heart_100iter.to_csv("./cv10_results_Genetic_Heart_100iter.csv")
cv10_results_Genetic_Heart_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8888888888888888  Precision:  0.8875  Recall:  0.8875  F1-Score:  0.8875
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8518518518518519  Precision:  0.8500000000000001  Recall:  0.8500000000000001  F1-Score:  0.8500000000000001
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8888888888888888  Precision:  0.8873626373626373  Recall:  0.8916666666666666  F1-Score:  0.8882758620689655
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8518518518518519  Precision:  0.8500000000000001  Recall:  0.8500000000000001  F1-Score:  0.8500000000000001
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_Jaya_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Heart_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Heart_100iter.to_csv("./cv10_results_Jaya_Heart_100iter.csv")
cv10_results_Jaya_Heart_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8518518518518519  Precision:  0.8500000000000001  Recall:  0.8500000000000001  F1-Score:  0.8500000000000001
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8518518518518519  Precision:  0.8502747252747254  Recall:  0.8541666666666667  F1-Score:  0.8510344827586207
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_PSO_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Heart_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Heart_100iter.to_csv("./cv10_results_PSO_Heart_100iter.csv")
cv10_results_PSO_Heart_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8518518518518519  Precision:  0.8500000000000001  Recall:  0.8500000000000001  F1-Score:  0.8500000000000001
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7962962962962963  Precision:  0.7937931034482759  Recall:  0.7958333333333334  F1-Score:  0.7945347630577655
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9074074074074074  Precision:  0.9055172413793103  Recall:  0.9083333333333333  F1-Score:  0.9066067104808024
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7222222222222222  Precision:  0.7222222222222222  Recall:  0.725  F1-Score:  0.7213622291021671
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_MGFPA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Heart_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Heart_100iter.to_csv("./cv10_results_MGFPA_Heart_100iter.csv")
cv10_results_MGFPA_Heart_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9074074074074074  Precision:  0.9055172413793103  Recall:  0.9083333333333333  F1-Score:  0.9066067104808024
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8703703703703703  Precision:  0.8703703703703703  Recall:  0.875  F1-Score:  0.869969040247678
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9074074074074074  Precision:  0.9055172413793103  Recall:  0.9083333333333333  F1-Score:  0.9066067104808024
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# # 380 Iteration

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_JA_GA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")


av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Heart_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Heart_380iter.to_csv("./cv10_results_JA_GA_Heart_380iter.csv")
cv10_results_JA_GA_Heart_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8888888888888888  Precision:  0.8875  Recall:  0.8875  F1-Score:  0.8875
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8703703703703703  Precision:  0.8703703703703703  Recall:  0.875  F1-Score:  0.869969040247678
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  6
#  Accuracy:  0.9074074074074074  Precision:  0.9055172413793103  Recall:  0.9083333333333333  F1-Score:  0.9066067104808024
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_ISSA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISSA_Heart_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Heart_380iter.to_csv("./cv10_results_ISSA_Heart_380iter.csv")
cv10_results_ISSA_Heart_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8518518518518519  Precision:  0.8502747252747254  Recall:  0.8541666666666667  F1-Score:  0.8510344827586207
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7592592592592593  Precision:  0.7592592592592593  Recall:  0.7625  F1-Score:  0.758513931888545
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8518518518518519  Precision:  0.8500000000000001  Recall:  0.8500000000000001  F1-Score:  0.8500000000000001
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8888888888888888  Precision:  0.8875  Recall:  0.8875  F1-Score:  0.8875
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_ISCA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISCA_Heart_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Heart_380iter.to_csv("./cv10_results_ISCA_Heart_380iter.csv")
cv10_results_ISCA_Heart_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8703703703703703  Precision:  0.8703703703703703  Recall:  0.875  F1-Score:  0.869969040247678
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8333333333333334  Precision:  0.832398316970547  Recall:  0.8291666666666666  F1-Score:  0.8304848273456575
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9074074074074074  Precision:  0.9055172413793103  Recall:  0.9083333333333333  F1-Score:  0.9066067104808024
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7222222222222222  Precision:  0.7222222222222222  Recall:  0.725  F1-Score:  0.7213622291021671
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_Genetic_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Heart_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Heart_380iter.to_csv("./cv10_results_Genetic_Heart_380iter.csv")
cv10_results_Genetic_Heart_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8888888888888888  Precision:  0.8875  Recall:  0.8875  F1-Score:  0.8875
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8333333333333334  Precision:  0.832398316970547  Recall:  0.8291666666666666  F1-Score:  0.8304848273456575
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8888888888888888  Precision:  0.8873626373626373  Recall:  0.8916666666666666  F1-Score:  0.8882758620689655
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8333333333333334  Precision:  0.832398316970547  Recall:  0.8291666666666666  F1-Score:  0.8304848273456575
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_Jaya_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Heart_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Heart_380iter.to_csv("./cv10_results_Jaya_Heart_380iter.csv")
cv10_results_Jaya_Heart_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7777777777777778  Precision:  0.7802197802197802  Recall:  0.7833333333333333  F1-Score:  0.7774725274725274
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7777777777777778  Precision:  0.7802197802197802  Recall:  0.7833333333333333  F1-Score:  0.7774725274725274
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8148148148148148  Precision:  0.8131868131868132  Recall:  0.8166666666666667  F1-Score:  0.8137931034482759
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8333333333333334  Precision:  0.8333333333333333  Recall:  0.8375  F1-Score:  0.8328173374613004
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7777777777777778  Precision:  0.7802197802197802  Recall:  0.7833333333333333  F1-Score:  0.7774725274725274
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_PSO_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Heart_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Heart_380iter.to_csv("./cv10_results_PSO_Heart_380iter.csv")
cv10_results_PSO_Heart_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8518518518518519  Precision:  0.8500000000000001  Recall:  0.8500000000000001  F1-Score:  0.8500000000000001
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7962962962962963  Precision:  0.7937931034482759  Recall:  0.7958333333333334  F1-Score:  0.7945347630577655
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9074074074074074  Precision:  0.9055172413793103  Recall:  0.9083333333333333  F1-Score:  0.9066067104808024
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7222222222222222  Precision:  0.7222222222222222  Recall:  0.725  F1-Score:  0.7213622291021671
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Heart_MGFPA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Heart[:, var_value_indexes]
    xtest = features_test_Heart[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Heart_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Heart_380iter.to_csv("./cv10_results_MGFPA_Heart_380iter.csv")
cv10_results_MGFPA_Heart_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7777777777777778  Precision:  0.775  Recall:  0.775  F1-Score:  0.7750000000000001
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9074074074074074  Precision:  0.9055172413793103  Recall:  0.9083333333333333  F1-Score:  0.9066067104808024
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8703703703703703  Precision:  0.8703703703703703  Recall:  0.875  F1-Score:  0.869969040247678
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9074074074074074  Precision:  0.9055172413793103  Recall:  0.9083333333333333  F1-Score:  0.9066067104808024
# ---------------------------------------------------------
# Run:  6
# ...
