# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
from cuml.svm import SVC, SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import seaborn as sns
from sklearn.tree import plot_tree
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")


from sklearn import set_config 

set_config(display="diagram")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
#Genetic
df = pd.read_csv("/kaggle/input/benchmarkjagen/Dermatology/Results_Genetic.csv")
df.head(11)
indexs_Genetic = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Genetic.append(np.array(numbers))
        
#ISCA        
df = pd.read_csv("/kaggle/input/benchmarkjagen/Dermatology/Results_ISCA.csv")
df.head(11)
indexs_ISCA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISCA.append(np.array(numbers))

#ISSA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Dermatology/Results_ISSA.csv")
df.head(11)
indexs_ISSA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISSA.append(np.array(numbers))
        
#JA_GA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Dermatology/Results_JA+GA.csv")
df.head(11)
indexs_JA_GA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_JA_GA.append(np.array(numbers))

#Jaya
df = pd.read_csv("/kaggle/input/benchmarkjagen/Dermatology/Results_Jaya.csv")
df.head(11)
indexs_Jaya = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Jaya.append(np.array(numbers))

#MGFPA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Dermatology/Results_MGFPA.csv")
df.head(11)
indexs_MGFPA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_MGFPA.append(np.array(numbers))

#PSO
df = pd.read_csv("/kaggle/input/benchmarkjagen/Dermatology/Results_PSO.csv")
df.head(11)
indexs_PSO = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_PSO.append(np.array(numbers))

# %%
#Original
features_test_Dermatology = np.load('/kaggle/input/benchmarkjagen/Dermatology/xtest.npy')
y_test = np.load("/kaggle/input/benchmarkjagen/Dermatology/ytest.npy")
features_train_Dermatology = np.load('/kaggle/input/benchmarkjagen/Dermatology/xtrain.npy')
y_train = np.load("/kaggle/input/benchmarkjagen/Dermatology/ytrain.npy")
#JA + GA (Jaya + Genetic)
featuresIndex_Dermatology_JA_GA_100iter_run1 = indexs_JA_GA[0]
featuresIndex_Dermatology_JA_GA_100iter_run2 = indexs_JA_GA[1]
featuresIndex_Dermatology_JA_GA_100iter_run3 = indexs_JA_GA[2]
featuresIndex_Dermatology_JA_GA_100iter_run4 = indexs_JA_GA[3]
featuresIndex_Dermatology_JA_GA_100iter_run5 = indexs_JA_GA[4]
featuresIndex_Dermatology_JA_GA_100iter_run6 = indexs_JA_GA[5]
featuresIndex_Dermatology_JA_GA_100iter_run7 = indexs_JA_GA[6]
featuresIndex_Dermatology_JA_GA_100iter_run8 = indexs_JA_GA[7]
featuresIndex_Dermatology_JA_GA_100iter_run9 = indexs_JA_GA[8]
featuresIndex_Dermatology_JA_GA_100iter_run10 = indexs_JA_GA[9]

featuresIndex_Dermatology_JA_GA_380iter_run1 = indexs_JA_GA[0]
featuresIndex_Dermatology_JA_GA_380iter_run2 = indexs_JA_GA[1]
featuresIndex_Dermatology_JA_GA_380iter_run3 = indexs_JA_GA[2]
featuresIndex_Dermatology_JA_GA_380iter_run4 = indexs_JA_GA[3]
featuresIndex_Dermatology_JA_GA_380iter_run5 = indexs_JA_GA[4]
featuresIndex_Dermatology_JA_GA_380iter_run6 = indexs_JA_GA[5]
featuresIndex_Dermatology_JA_GA_380iter_run7 = indexs_JA_GA[6]
featuresIndex_Dermatology_JA_GA_380iter_run8 = indexs_JA_GA[7]
featuresIndex_Dermatology_JA_GA_380iter_run9 = indexs_JA_GA[8]
featuresIndex_Dermatology_JA_GA_380iter_run10 = indexs_JA_GA[9]

#ISSA
featuresIndex_Dermatology_ISSA_100iter_run1 = indexs_ISSA[0]
featuresIndex_Dermatology_ISSA_100iter_run2 = indexs_ISSA[1]
featuresIndex_Dermatology_ISSA_100iter_run3 = indexs_ISSA[2]
featuresIndex_Dermatology_ISSA_100iter_run4 = indexs_ISSA[3]
featuresIndex_Dermatology_ISSA_100iter_run5 = indexs_ISSA[4]
featuresIndex_Dermatology_ISSA_100iter_run6 = indexs_ISSA[5]
featuresIndex_Dermatology_ISSA_100iter_run7 = indexs_ISSA[6]
featuresIndex_Dermatology_ISSA_100iter_run8 = indexs_ISSA[7]
featuresIndex_Dermatology_ISSA_100iter_run9 = indexs_ISSA[8]
featuresIndex_Dermatology_ISSA_100iter_run10 = indexs_ISSA[9]

featuresIndex_Dermatology_ISSA_380iter_run1 = indexs_ISSA[0]
featuresIndex_Dermatology_ISSA_380iter_run2 = indexs_ISSA[1]
featuresIndex_Dermatology_ISSA_380iter_run3 = indexs_ISSA[2]
featuresIndex_Dermatology_ISSA_380iter_run4 = indexs_ISSA[3]
featuresIndex_Dermatology_ISSA_380iter_run5 = indexs_ISSA[4]
featuresIndex_Dermatology_ISSA_380iter_run6 = indexs_ISSA[5]
featuresIndex_Dermatology_ISSA_380iter_run7 = indexs_ISSA[6]
featuresIndex_Dermatology_ISSA_380iter_run8 = indexs_ISSA[7]
featuresIndex_Dermatology_ISSA_380iter_run9 = indexs_ISSA[8]
featuresIndex_Dermatology_ISSA_380iter_run10 = indexs_ISSA[9]

#Jaya
featuresIndex_Dermatology_Jaya_100iter_run1 = indexs_Jaya[0]
featuresIndex_Dermatology_Jaya_100iter_run2 = indexs_Jaya[1]
featuresIndex_Dermatology_Jaya_100iter_run3 = indexs_Jaya[2]
featuresIndex_Dermatology_Jaya_100iter_run4 = indexs_Jaya[3]
featuresIndex_Dermatology_Jaya_100iter_run5 = indexs_Jaya[4]
featuresIndex_Dermatology_Jaya_100iter_run6 = indexs_Jaya[5]
featuresIndex_Dermatology_Jaya_100iter_run7 = indexs_Jaya[6]
featuresIndex_Dermatology_Jaya_100iter_run8 = indexs_Jaya[7]
featuresIndex_Dermatology_Jaya_100iter_run9 = indexs_Jaya[8]
featuresIndex_Dermatology_Jaya_100iter_run10 = indexs_Jaya[9]

featuresIndex_Dermatology_Jaya_380iter_run1 = indexs_Jaya[0]
featuresIndex_Dermatology_Jaya_380iter_run2 = indexs_Jaya[1]
featuresIndex_Dermatology_Jaya_380iter_run3 = indexs_Jaya[2]
featuresIndex_Dermatology_Jaya_380iter_run4 = indexs_Jaya[3]
featuresIndex_Dermatology_Jaya_380iter_run5 = indexs_Jaya[4]
featuresIndex_Dermatology_Jaya_380iter_run6 = indexs_Jaya[5]
featuresIndex_Dermatology_Jaya_380iter_run7 = indexs_Jaya[6]
featuresIndex_Dermatology_Jaya_380iter_run8 = indexs_Jaya[7]
featuresIndex_Dermatology_Jaya_380iter_run9 = indexs_Jaya[8]
featuresIndex_Dermatology_Jaya_380iter_run10 = indexs_Jaya[9]

#PSO
featuresIndex_Dermatology_PSO_100iter_run1 = indexs_PSO[0]
featuresIndex_Dermatology_PSO_100iter_run2 = indexs_PSO[1]
featuresIndex_Dermatology_PSO_100iter_run3 = indexs_PSO[2]
featuresIndex_Dermatology_PSO_100iter_run4 = indexs_PSO[3]
featuresIndex_Dermatology_PSO_100iter_run5 = indexs_PSO[4]
featuresIndex_Dermatology_PSO_100iter_run6 = indexs_PSO[5]
featuresIndex_Dermatology_PSO_100iter_run7 = indexs_PSO[6]
featuresIndex_Dermatology_PSO_100iter_run8 = indexs_PSO[7]
featuresIndex_Dermatology_PSO_100iter_run9 = indexs_PSO[8]
featuresIndex_Dermatology_PSO_100iter_run10 = indexs_PSO[9]

featuresIndex_Dermatology_PSO_380iter_run1 = indexs_PSO[0]
featuresIndex_Dermatology_PSO_380iter_run2 = indexs_PSO[1]
featuresIndex_Dermatology_PSO_380iter_run3 = indexs_PSO[2]
featuresIndex_Dermatology_PSO_380iter_run4 = indexs_PSO[3]
featuresIndex_Dermatology_PSO_380iter_run5 = indexs_PSO[4]
featuresIndex_Dermatology_PSO_380iter_run6 = indexs_PSO[5]
featuresIndex_Dermatology_PSO_380iter_run7 = indexs_PSO[6]
featuresIndex_Dermatology_PSO_380iter_run8 = indexs_PSO[7]
featuresIndex_Dermatology_PSO_380iter_run9 = indexs_PSO[8]
featuresIndex_Dermatology_PSO_380iter_run10 = indexs_PSO[9]

#MGFPA
featuresIndex_Dermatology_MGFPA_100iter_run1 = indexs_MGFPA[0]
featuresIndex_Dermatology_MGFPA_100iter_run2 = indexs_MGFPA[1]
featuresIndex_Dermatology_MGFPA_100iter_run3 = indexs_MGFPA[2]
featuresIndex_Dermatology_MGFPA_100iter_run4 = indexs_MGFPA[3]
featuresIndex_Dermatology_MGFPA_100iter_run5 = indexs_MGFPA[4]
featuresIndex_Dermatology_MGFPA_100iter_run6 = indexs_MGFPA[5]
featuresIndex_Dermatology_MGFPA_100iter_run7 = indexs_MGFPA[6]
featuresIndex_Dermatology_MGFPA_100iter_run8 = indexs_MGFPA[7]
featuresIndex_Dermatology_MGFPA_100iter_run9 = indexs_MGFPA[8]
featuresIndex_Dermatology_MGFPA_100iter_run10 = indexs_MGFPA[9]

featuresIndex_Dermatology_MGFPA_380iter_run1 = indexs_MGFPA[0]
featuresIndex_Dermatology_MGFPA_380iter_run2 = indexs_MGFPA[1]
featuresIndex_Dermatology_MGFPA_380iter_run3 = indexs_MGFPA[2]
featuresIndex_Dermatology_MGFPA_380iter_run4 = indexs_MGFPA[3]
featuresIndex_Dermatology_MGFPA_380iter_run5 = indexs_MGFPA[4]
featuresIndex_Dermatology_MGFPA_380iter_run6 = indexs_MGFPA[5]
featuresIndex_Dermatology_MGFPA_380iter_run7 = indexs_MGFPA[6]
featuresIndex_Dermatology_MGFPA_380iter_run8 = indexs_MGFPA[7]
featuresIndex_Dermatology_MGFPA_380iter_run9 = indexs_MGFPA[8]
featuresIndex_Dermatology_MGFPA_380iter_run10 = indexs_MGFPA[9]

#Genetic
featuresIndex_Dermatology_Genetic_100iter_run1 = indexs_Genetic[0]
featuresIndex_Dermatology_Genetic_100iter_run2 = indexs_Genetic[1]
featuresIndex_Dermatology_Genetic_100iter_run3 = indexs_Genetic[2]
featuresIndex_Dermatology_Genetic_100iter_run4 = indexs_Genetic[3]
featuresIndex_Dermatology_Genetic_100iter_run5 = indexs_Genetic[4]
featuresIndex_Dermatology_Genetic_100iter_run6 = indexs_Genetic[5]
featuresIndex_Dermatology_Genetic_100iter_run7 = indexs_Genetic[6]
featuresIndex_Dermatology_Genetic_100iter_run8 = indexs_Genetic[7]
featuresIndex_Dermatology_Genetic_100iter_run9 = indexs_Genetic[8]
featuresIndex_Dermatology_Genetic_100iter_run10 = indexs_Genetic[9]

featuresIndex_Dermatology_Genetic_380iter_run1 = indexs_Genetic[0]
featuresIndex_Dermatology_Genetic_380iter_run2 = indexs_Genetic[1]
featuresIndex_Dermatology_Genetic_380iter_run3 = indexs_Genetic[2]
featuresIndex_Dermatology_Genetic_380iter_run4 = indexs_Genetic[3]
featuresIndex_Dermatology_Genetic_380iter_run5 = indexs_Genetic[4]
featuresIndex_Dermatology_Genetic_380iter_run6 = indexs_Genetic[5]
featuresIndex_Dermatology_Genetic_380iter_run7 = indexs_Genetic[6]
featuresIndex_Dermatology_Genetic_380iter_run8 = indexs_Genetic[7]
featuresIndex_Dermatology_Genetic_380iter_run9 = indexs_Genetic[8]
featuresIndex_Dermatology_Genetic_380iter_run10 = indexs_Genetic[9]

#ISCA
featuresIndex_Dermatology_ISCA_100iter_run1 = indexs_ISCA[0]
featuresIndex_Dermatology_ISCA_100iter_run2 = indexs_ISCA[1]
featuresIndex_Dermatology_ISCA_100iter_run3 = indexs_ISCA[2]
featuresIndex_Dermatology_ISCA_100iter_run4 = indexs_ISCA[3]
featuresIndex_Dermatology_ISCA_100iter_run5 = indexs_ISCA[4]
featuresIndex_Dermatology_ISCA_100iter_run6 = indexs_ISCA[5]
featuresIndex_Dermatology_ISCA_100iter_run7 = indexs_ISCA[6]
featuresIndex_Dermatology_ISCA_100iter_run8 = indexs_ISCA[7]
featuresIndex_Dermatology_ISCA_100iter_run9 = indexs_ISCA[8]
featuresIndex_Dermatology_ISCA_100iter_run10 = indexs_ISCA[9]

featuresIndex_Dermatology_ISCA_380iter_run1 = indexs_ISCA[0]
featuresIndex_Dermatology_ISCA_380iter_run2 = indexs_ISCA[1]
featuresIndex_Dermatology_ISCA_380iter_run3 = indexs_ISCA[2]
featuresIndex_Dermatology_ISCA_380iter_run4 = indexs_ISCA[3]
featuresIndex_Dermatology_ISCA_380iter_run5 = indexs_ISCA[4]
featuresIndex_Dermatology_ISCA_380iter_run6 = indexs_ISCA[5]
featuresIndex_Dermatology_ISCA_380iter_run7 = indexs_ISCA[6]
featuresIndex_Dermatology_ISCA_380iter_run8 = indexs_ISCA[7]
featuresIndex_Dermatology_ISCA_380iter_run9 = indexs_ISCA[8]
featuresIndex_Dermatology_ISCA_380iter_run10 = indexs_ISCA[9]

# %% [markdown]
# # 100 Iteration (10 Individual Runs)

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_JA_GA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Dermatology_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Dermatology_100iter.to_csv("./cv10_results_JA_GA_Dermatology_100iter.csv")
cv10_results_JA_GA_Dermatology_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8904109589041096  Precision:  0.8745454545454545  Recall:  0.8825396825396825  F1-Score:  0.8744551825692177
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9452054794520548  Precision:  0.954594017094017  Recall:  0.9464285714285715  F1-Score:  0.9447324069587406
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9452054794520548  Precision:  0.94760101010101  Recall:  0.9436507936507935  F1-Score:  0.9447324069587406
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9452054794520548  Precision:  0.94760101010101  Recall:  0.9436507936507935  F1-Score:  0.9447324069587406
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9315068493150684  Precision:  0.9076923076923077  Recall:  0.9336266390614217  F1-Score:  0.9182716049382716
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_ISSA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISSA_Dermatology_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Dermatology_100iter.to_csv("./cv10_results_ISSA_Dermatology_100iter.csv")
cv10_results_ISSA_Dermatology_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.726027397260274  Precision:  0.889792231255646  Recall:  0.6361111111111112  F1-Score:  0.6899044486215539
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8767123287671232  Precision:  0.860774410774411  Recall:  0.8055555555555557  F1-Score:  0.821692979251197
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7397260273972602  Precision:  0.8805555555555555  Recall:  0.6468253968253967  F1-Score:  0.6976190476190475
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.5342465753424658  Precision:  0.6934523809523809  Recall:  0.4059523809523809  F1-Score:  0.4355435644992607
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.726027397260274  Precision:  0.8916440831074978  Recall:  0.6238095238095238  F1-Score:  0.6705307064217249
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_ISCA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISCA_Dermatology_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Dermatology_100iter.to_csv("./cv10_results_ISCA_Dermatology_100iter.csv")
cv10_results_ISCA_Dermatology_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.684931506849315  Precision:  0.832010582010582  Recall:  0.582936507936508  F1-Score:  0.6314964762333183
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8493150684931506  Precision:  0.9009259259259258  Recall:  0.8123015873015872  F1-Score:  0.8419600500621588
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8082191780821918  Precision:  0.9104497354497353  Recall:  0.7134920634920635  F1-Score:  0.7558681185722929
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8356164383561644  Precision:  0.9143097643097643  Recall:  0.7976190476190476  F1-Score:  0.8403979869459746
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.821917808219178  Precision:  0.9136710239651417  Recall:  0.7253968253968254  F1-Score:  0.7659649122807018
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_Genetic_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Dermatology_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Dermatology_100iter.to_csv("./cv10_results_Genetic_Dermatology_100iter.csv")
cv10_results_Genetic_Dermatology_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8904109589041096  Precision:  0.9221661054994389  Recall:  0.8891821946169772  F1-Score:  0.9011960878627545
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9315068493150684  Precision:  0.9056818181818183  Recall:  0.9269841269841269  F1-Score:  0.909770000943703
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9041095890410958  Precision:  0.9111111111111111  Recall:  0.9086266390614218  F1-Score:  0.9074312868639111
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.958904109589041  Precision:  0.9625  Recall:  0.9575396825396826  F1-Score:  0.9597255056474915
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9452054794520548  Precision:  0.9548484848484847  Recall:  0.9436507936507935  F1-Score:  0.9484769189479335
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_Jaya_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Dermatology_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Dermatology_100iter.to_csv("./cv10_results_Jaya_Dermatology_100iter.csv")
cv10_results_Jaya_Dermatology_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7123287671232876  Precision:  0.8759920634920636  Recall:  0.6384920634920634  F1-Score:  0.7012820512820511
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8082191780821918  Precision:  0.8985195088136265  Recall:  0.7115079365079365  F1-Score:  0.7524736450937825
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.821917808219178  Precision:  0.9136710239651417  Recall:  0.7253968253968254  F1-Score:  0.7659649122807018
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.547945205479452  Precision:  0.8306603773584905  Recall:  0.44484126984126987  F1-Score:  0.4867159729388832
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.726027397260274  Precision:  0.887868229331644  Recall:  0.6305555555555556  F1-Score:  0.6851440394998579
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_PSO_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Dermatology_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Dermatology_100iter.to_csv("./cv10_results_PSO_Dermatology_100iter.csv")
cv10_results_PSO_Dermatology_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8356164383561644  Precision:  0.8642361111111111  Recall:  0.7678571428571428  F1-Score:  0.7998418248418248
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.958904109589041  Precision:  0.9625  Recall:  0.9575396825396826  F1-Score:  0.9597255056474915
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9041095890410958  Precision:  0.9384199134199133  Recall:  0.8686507936507937  F1-Score:  0.8967534517832898
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.821917808219178  Precision:  0.8848738626964434  Recall:  0.7365079365079366  F1-Score:  0.7603048280927762
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8904109589041096  Precision:  0.9151234567901234  Recall:  0.8575396825396825  F1-Score:  0.8779268035408386
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_MGFPA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Dermatology_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Dermatology_100iter.to_csv("./cv10_results_MGFPA_Dermatology_100iter.csv")
cv10_results_MGFPA_Dermatology_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.9315068493150684  Precision:  0.9438034188034189  Recall:  0.9086266390614218  F1-Score:  0.9227126721452961
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.863013698630137  Precision:  0.9082522841143531  Recall:  0.8234126984126985  F1-Score:  0.8523300773300773
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8767123287671232  Precision:  0.8966049382716049  Recall:  0.8380952380952382  F1-Score:  0.8623860577369348
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.958904109589041  Precision:  0.9625  Recall:  0.9575396825396826  F1-Score:  0.9597255056474915
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9041095890410958  Precision:  0.8918803418803418  Recall:  0.9011904761904762  F1-Score:  0.8879004454192424
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# # 380 Iteration

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_JA_GA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")


av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Dermatology_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Dermatology_380iter.to_csv("./cv10_results_JA_GA_Dermatology_380iter.csv")
cv10_results_JA_GA_Dermatology_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.863013698630137  Precision:  0.8696581196581196  Recall:  0.8492063492063492  F1-Score:  0.8578920847091274
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9315068493150684  Precision:  0.9412121212121213  Recall:  0.9317460317460317  F1-Score:  0.9346863884907363
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9452054794520548  Precision:  0.9548484848484847  Recall:  0.9436507936507935  F1-Score:  0.9484769189479335
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9452054794520548  Precision:  0.9548484848484847  Recall:  0.9436507936507935  F1-Score:  0.9484769189479335
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9452054794520548  Precision:  0.956111111111111  Recall:  0.9408730158730158  F1-Score:  0.9475552306692657
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_ISSA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISSA_Dermatology_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Dermatology_380iter.to_csv("./cv10_results_ISSA_Dermatology_380iter.csv")
cv10_results_ISSA_Dermatology_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.958904109589041  Precision:  0.9625  Recall:  0.9575396825396826  F1-Score:  0.9597255056474915
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9452054794520548  Precision:  0.9126262626262626  Recall:  0.938888888888889  F1-Score:  0.9194889397406559
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9452054794520548  Precision:  0.9548484848484847  Recall:  0.9436507936507935  F1-Score:  0.9484769189479335
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9041095890410958  Precision:  0.8879349046015713  Recall:  0.8436507936507937  F1-Score:  0.8618875288059117
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9178082191780822  Precision:  0.8917435221783049  Recall:  0.9197377501725327  F1-Score:  0.8989268662800317
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_ISCA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISCA_Dermatology_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Dermatology_380iter.to_csv("./cv10_results_ISCA_Dermatology_380iter.csv")
cv10_results_ISCA_Dermatology_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.9178082191780822  Precision:  0.9180555555555556  Recall:  0.9130952380952381  F1-Score:  0.915281061203047
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9178082191780822  Precision:  0.8987179487179486  Recall:  0.9130952380952381  F1-Score:  0.900001797789746
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.958904109589041  Precision:  0.9558080808080808  Recall:  0.9575396825396826  F1-Score:  0.9561287477954146
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9452054794520548  Precision:  0.9212121212121213  Recall:  0.9436507936507935  F1-Score:  0.9297599877310022
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.958904109589041  Precision:  0.9558080808080808  Recall:  0.9575396825396826  F1-Score:  0.9561287477954146
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_Genetic_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Dermatology_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Dermatology_380iter.to_csv("./cv10_results_Genetic_Dermatology_380iter.csv")
cv10_results_Genetic_Dermatology_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8904109589041096  Precision:  0.9221661054994389  Recall:  0.8891821946169772  F1-Score:  0.9011960878627545
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9315068493150684  Precision:  0.9056818181818183  Recall:  0.9269841269841269  F1-Score:  0.909770000943703
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9041095890410958  Precision:  0.9111111111111111  Recall:  0.9086266390614218  F1-Score:  0.9074312868639111
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.958904109589041  Precision:  0.9625  Recall:  0.9575396825396826  F1-Score:  0.9597255056474915
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9452054794520548  Precision:  0.9548484848484847  Recall:  0.9436507936507935  F1-Score:  0.9484769189479335
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_Jaya_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Dermatology_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Dermatology_380iter.to_csv("./cv10_results_Jaya_Dermatology_380iter.csv")
cv10_results_Jaya_Dermatology_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8767123287671232  Precision:  0.8775396825396825  Recall:  0.8658730158730158  F1-Score:  0.8700396825396824
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.958904109589041  Precision:  0.9570707070707071  Recall:  0.9555555555555556  F1-Score:  0.9558470764617691
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.958904109589041  Precision:  0.9558080808080808  Recall:  0.9575396825396826  F1-Score:  0.9561287477954146
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9178082191780822  Precision:  0.899537037037037  Recall:  0.9158730158730158  F1-Score:  0.9017769726989586
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.958904109589041  Precision:  0.936111111111111  Recall:  0.9527777777777778  F1-Score:  0.9421539961013646
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_PSO_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Dermatology_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Dermatology_380iter.to_csv("./cv10_results_PSO_Dermatology_380iter.csv")
cv10_results_PSO_Dermatology_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.9178082191780822  Precision:  0.9156177156177155  Recall:  0.9103174603174603  F1-Score:  0.9081802447226878
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.958904109589041  Precision:  0.9625  Recall:  0.9575396825396826  F1-Score:  0.9597255056474915
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9452054794520548  Precision:  0.9548484848484847  Recall:  0.938888888888889  F1-Score:  0.9458778286295448
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8767123287671232  Precision:  0.9031932573599241  Recall:  0.8436507936507937  F1-Score:  0.8616804894684376
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8904109589041096  Precision:  0.9151234567901234  Recall:  0.8575396825396825  F1-Score:  0.8779268035408386
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Dermatology_MGFPA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Dermatology[:, var_value_indexes]
    xtest = features_test_Dermatology[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Dermatology_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Dermatology_380iter.to_csv("./cv10_results_MGFPA_Dermatology_380iter.csv")
cv10_results_MGFPA_Dermatology_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.9315068493150684  Precision:  0.9364801864801865  Recall:  0.9430469289164941  F1-Score:  0.9389065255731923
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9178082191780822  Precision:  0.9361305361305362  Recall:  0.915079365079365  F1-Score:  0.9240996729228178
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8767123287671232  Precision:  0.8808974358974359  Recall:  0.8658730158730158  F1-Score:  0.8713271604938271
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9726027397260274  Precision:  0.9694444444444444  Recall:  0.9694444444444444  F1-Score:  0.9694444444444444
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9041095890410958  Precision:  0.8779040404040405  Recall:  0.8936507936507936  F1-Score:  0.8669079438401598
# ---------------------------------------------------------
# Run:  6
# ...
