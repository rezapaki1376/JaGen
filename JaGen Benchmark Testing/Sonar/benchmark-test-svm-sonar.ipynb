# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
from cuml.svm import SVC, SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import seaborn as sns
from sklearn.tree import plot_tree
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")


from sklearn import set_config 

set_config(display="diagram")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
#Genetic
df = pd.read_csv("/kaggle/input/benchmarkjagen/Sonar/Results_Genetic.csv")
df.head(11)
indexs_Genetic = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Genetic.append(np.array(numbers))
        
#ISCA        
df = pd.read_csv("/kaggle/input/benchmarkjagen/Sonar/Results_ISCA.csv")
df.head(11)
indexs_ISCA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISCA.append(np.array(numbers))

#ISSA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Sonar/Results_ISSA.csv")
df.head(11)
indexs_ISSA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISSA.append(np.array(numbers))
        
#JA_GA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Sonar/Results_JA+GA.csv")
df.head(11)
indexs_JA_GA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_JA_GA.append(np.array(numbers))

#Jaya
df = pd.read_csv("/kaggle/input/benchmarkjagen/Sonar/Results_Jaya.csv")
df.head(11)
indexs_Jaya = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Jaya.append(np.array(numbers))

#MGFPA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Sonar/Results_MGFPA.csv")
df.head(11)
indexs_MGFPA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_MGFPA.append(np.array(numbers))

#PSO
df = pd.read_csv("/kaggle/input/benchmarkjagen/Sonar/Results_PSO.csv")
df.head(11)
indexs_PSO = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_PSO.append(np.array(numbers))

# %%
#Original
features_test_Sonar = np.load('/kaggle/input/benchmarkjagen/Sonar/xtest.npy')
y_test = np.load("/kaggle/input/benchmarkjagen/Sonar/ytest.npy")
features_train_Sonar = np.load('/kaggle/input/benchmarkjagen/Sonar/xtrain.npy')
y_train = np.load("/kaggle/input/benchmarkjagen/Sonar/ytrain.npy")
#JA + GA (Jaya + Genetic)
featuresIndex_Sonar_JA_GA_100iter_run1 = indexs_JA_GA[0]
featuresIndex_Sonar_JA_GA_100iter_run2 = indexs_JA_GA[1]
featuresIndex_Sonar_JA_GA_100iter_run3 = indexs_JA_GA[2]
featuresIndex_Sonar_JA_GA_100iter_run4 = indexs_JA_GA[3]
featuresIndex_Sonar_JA_GA_100iter_run5 = indexs_JA_GA[4]
featuresIndex_Sonar_JA_GA_100iter_run6 = indexs_JA_GA[5]
featuresIndex_Sonar_JA_GA_100iter_run7 = indexs_JA_GA[6]
featuresIndex_Sonar_JA_GA_100iter_run8 = indexs_JA_GA[7]
featuresIndex_Sonar_JA_GA_100iter_run9 = indexs_JA_GA[8]
featuresIndex_Sonar_JA_GA_100iter_run10 = indexs_JA_GA[9]

featuresIndex_Sonar_JA_GA_380iter_run1 = indexs_JA_GA[0]
featuresIndex_Sonar_JA_GA_380iter_run2 = indexs_JA_GA[1]
featuresIndex_Sonar_JA_GA_380iter_run3 = indexs_JA_GA[2]
featuresIndex_Sonar_JA_GA_380iter_run4 = indexs_JA_GA[3]
featuresIndex_Sonar_JA_GA_380iter_run5 = indexs_JA_GA[4]
featuresIndex_Sonar_JA_GA_380iter_run6 = indexs_JA_GA[5]
featuresIndex_Sonar_JA_GA_380iter_run7 = indexs_JA_GA[6]
featuresIndex_Sonar_JA_GA_380iter_run8 = indexs_JA_GA[7]
featuresIndex_Sonar_JA_GA_380iter_run9 = indexs_JA_GA[8]
featuresIndex_Sonar_JA_GA_380iter_run10 = indexs_JA_GA[9]

#ISSA
featuresIndex_Sonar_ISSA_100iter_run1 = indexs_ISSA[0]
featuresIndex_Sonar_ISSA_100iter_run2 = indexs_ISSA[1]
featuresIndex_Sonar_ISSA_100iter_run3 = indexs_ISSA[2]
featuresIndex_Sonar_ISSA_100iter_run4 = indexs_ISSA[3]
featuresIndex_Sonar_ISSA_100iter_run5 = indexs_ISSA[4]
featuresIndex_Sonar_ISSA_100iter_run6 = indexs_ISSA[5]
featuresIndex_Sonar_ISSA_100iter_run7 = indexs_ISSA[6]
featuresIndex_Sonar_ISSA_100iter_run8 = indexs_ISSA[7]
featuresIndex_Sonar_ISSA_100iter_run9 = indexs_ISSA[8]
featuresIndex_Sonar_ISSA_100iter_run10 = indexs_ISSA[9]

featuresIndex_Sonar_ISSA_380iter_run1 = indexs_ISSA[0]
featuresIndex_Sonar_ISSA_380iter_run2 = indexs_ISSA[1]
featuresIndex_Sonar_ISSA_380iter_run3 = indexs_ISSA[2]
featuresIndex_Sonar_ISSA_380iter_run4 = indexs_ISSA[3]
featuresIndex_Sonar_ISSA_380iter_run5 = indexs_ISSA[4]
featuresIndex_Sonar_ISSA_380iter_run6 = indexs_ISSA[5]
featuresIndex_Sonar_ISSA_380iter_run7 = indexs_ISSA[6]
featuresIndex_Sonar_ISSA_380iter_run8 = indexs_ISSA[7]
featuresIndex_Sonar_ISSA_380iter_run9 = indexs_ISSA[8]
featuresIndex_Sonar_ISSA_380iter_run10 = indexs_ISSA[9]

#Jaya
featuresIndex_Sonar_Jaya_100iter_run1 = indexs_Jaya[0]
featuresIndex_Sonar_Jaya_100iter_run2 = indexs_Jaya[1]
featuresIndex_Sonar_Jaya_100iter_run3 = indexs_Jaya[2]
featuresIndex_Sonar_Jaya_100iter_run4 = indexs_Jaya[3]
featuresIndex_Sonar_Jaya_100iter_run5 = indexs_Jaya[4]
featuresIndex_Sonar_Jaya_100iter_run6 = indexs_Jaya[5]
featuresIndex_Sonar_Jaya_100iter_run7 = indexs_Jaya[6]
featuresIndex_Sonar_Jaya_100iter_run8 = indexs_Jaya[7]
featuresIndex_Sonar_Jaya_100iter_run9 = indexs_Jaya[8]
featuresIndex_Sonar_Jaya_100iter_run10 = indexs_Jaya[9]

featuresIndex_Sonar_Jaya_380iter_run1 = indexs_Jaya[0]
featuresIndex_Sonar_Jaya_380iter_run2 = indexs_Jaya[1]
featuresIndex_Sonar_Jaya_380iter_run3 = indexs_Jaya[2]
featuresIndex_Sonar_Jaya_380iter_run4 = indexs_Jaya[3]
featuresIndex_Sonar_Jaya_380iter_run5 = indexs_Jaya[4]
featuresIndex_Sonar_Jaya_380iter_run6 = indexs_Jaya[5]
featuresIndex_Sonar_Jaya_380iter_run7 = indexs_Jaya[6]
featuresIndex_Sonar_Jaya_380iter_run8 = indexs_Jaya[7]
featuresIndex_Sonar_Jaya_380iter_run9 = indexs_Jaya[8]
featuresIndex_Sonar_Jaya_380iter_run10 = indexs_Jaya[9]

#PSO
featuresIndex_Sonar_PSO_100iter_run1 = indexs_PSO[0]
featuresIndex_Sonar_PSO_100iter_run2 = indexs_PSO[1]
featuresIndex_Sonar_PSO_100iter_run3 = indexs_PSO[2]
featuresIndex_Sonar_PSO_100iter_run4 = indexs_PSO[3]
featuresIndex_Sonar_PSO_100iter_run5 = indexs_PSO[4]
featuresIndex_Sonar_PSO_100iter_run6 = indexs_PSO[5]
featuresIndex_Sonar_PSO_100iter_run7 = indexs_PSO[6]
featuresIndex_Sonar_PSO_100iter_run8 = indexs_PSO[7]
featuresIndex_Sonar_PSO_100iter_run9 = indexs_PSO[8]
featuresIndex_Sonar_PSO_100iter_run10 = indexs_PSO[9]

featuresIndex_Sonar_PSO_380iter_run1 = indexs_PSO[0]
featuresIndex_Sonar_PSO_380iter_run2 = indexs_PSO[1]
featuresIndex_Sonar_PSO_380iter_run3 = indexs_PSO[2]
featuresIndex_Sonar_PSO_380iter_run4 = indexs_PSO[3]
featuresIndex_Sonar_PSO_380iter_run5 = indexs_PSO[4]
featuresIndex_Sonar_PSO_380iter_run6 = indexs_PSO[5]
featuresIndex_Sonar_PSO_380iter_run7 = indexs_PSO[6]
featuresIndex_Sonar_PSO_380iter_run8 = indexs_PSO[7]
featuresIndex_Sonar_PSO_380iter_run9 = indexs_PSO[8]
featuresIndex_Sonar_PSO_380iter_run10 = indexs_PSO[9]

#MGFPA
featuresIndex_Sonar_MGFPA_100iter_run1 = indexs_MGFPA[0]
featuresIndex_Sonar_MGFPA_100iter_run2 = indexs_MGFPA[1]
featuresIndex_Sonar_MGFPA_100iter_run3 = indexs_MGFPA[2]
featuresIndex_Sonar_MGFPA_100iter_run4 = indexs_MGFPA[3]
featuresIndex_Sonar_MGFPA_100iter_run5 = indexs_MGFPA[4]
featuresIndex_Sonar_MGFPA_100iter_run6 = indexs_MGFPA[5]
featuresIndex_Sonar_MGFPA_100iter_run7 = indexs_MGFPA[6]
featuresIndex_Sonar_MGFPA_100iter_run8 = indexs_MGFPA[7]
featuresIndex_Sonar_MGFPA_100iter_run9 = indexs_MGFPA[8]
featuresIndex_Sonar_MGFPA_100iter_run10 = indexs_MGFPA[9]

featuresIndex_Sonar_MGFPA_380iter_run1 = indexs_MGFPA[0]
featuresIndex_Sonar_MGFPA_380iter_run2 = indexs_MGFPA[1]
featuresIndex_Sonar_MGFPA_380iter_run3 = indexs_MGFPA[2]
featuresIndex_Sonar_MGFPA_380iter_run4 = indexs_MGFPA[3]
featuresIndex_Sonar_MGFPA_380iter_run5 = indexs_MGFPA[4]
featuresIndex_Sonar_MGFPA_380iter_run6 = indexs_MGFPA[5]
featuresIndex_Sonar_MGFPA_380iter_run7 = indexs_MGFPA[6]
featuresIndex_Sonar_MGFPA_380iter_run8 = indexs_MGFPA[7]
featuresIndex_Sonar_MGFPA_380iter_run9 = indexs_MGFPA[8]
featuresIndex_Sonar_MGFPA_380iter_run10 = indexs_MGFPA[9]

#Genetic
featuresIndex_Sonar_Genetic_100iter_run1 = indexs_Genetic[0]
featuresIndex_Sonar_Genetic_100iter_run2 = indexs_Genetic[1]
featuresIndex_Sonar_Genetic_100iter_run3 = indexs_Genetic[2]
featuresIndex_Sonar_Genetic_100iter_run4 = indexs_Genetic[3]
featuresIndex_Sonar_Genetic_100iter_run5 = indexs_Genetic[4]
featuresIndex_Sonar_Genetic_100iter_run6 = indexs_Genetic[5]
featuresIndex_Sonar_Genetic_100iter_run7 = indexs_Genetic[6]
featuresIndex_Sonar_Genetic_100iter_run8 = indexs_Genetic[7]
featuresIndex_Sonar_Genetic_100iter_run9 = indexs_Genetic[8]
featuresIndex_Sonar_Genetic_100iter_run10 = indexs_Genetic[9]

featuresIndex_Sonar_Genetic_380iter_run1 = indexs_Genetic[0]
featuresIndex_Sonar_Genetic_380iter_run2 = indexs_Genetic[1]
featuresIndex_Sonar_Genetic_380iter_run3 = indexs_Genetic[2]
featuresIndex_Sonar_Genetic_380iter_run4 = indexs_Genetic[3]
featuresIndex_Sonar_Genetic_380iter_run5 = indexs_Genetic[4]
featuresIndex_Sonar_Genetic_380iter_run6 = indexs_Genetic[5]
featuresIndex_Sonar_Genetic_380iter_run7 = indexs_Genetic[6]
featuresIndex_Sonar_Genetic_380iter_run8 = indexs_Genetic[7]
featuresIndex_Sonar_Genetic_380iter_run9 = indexs_Genetic[8]
featuresIndex_Sonar_Genetic_380iter_run10 = indexs_Genetic[9]

#ISCA
featuresIndex_Sonar_ISCA_100iter_run1 = indexs_ISCA[0]
featuresIndex_Sonar_ISCA_100iter_run2 = indexs_ISCA[1]
featuresIndex_Sonar_ISCA_100iter_run3 = indexs_ISCA[2]
featuresIndex_Sonar_ISCA_100iter_run4 = indexs_ISCA[3]
featuresIndex_Sonar_ISCA_100iter_run5 = indexs_ISCA[4]
featuresIndex_Sonar_ISCA_100iter_run6 = indexs_ISCA[5]
featuresIndex_Sonar_ISCA_100iter_run7 = indexs_ISCA[6]
featuresIndex_Sonar_ISCA_100iter_run8 = indexs_ISCA[7]
featuresIndex_Sonar_ISCA_100iter_run9 = indexs_ISCA[8]
featuresIndex_Sonar_ISCA_100iter_run10 = indexs_ISCA[9]

featuresIndex_Sonar_ISCA_380iter_run1 = indexs_ISCA[0]
featuresIndex_Sonar_ISCA_380iter_run2 = indexs_ISCA[1]
featuresIndex_Sonar_ISCA_380iter_run3 = indexs_ISCA[2]
featuresIndex_Sonar_ISCA_380iter_run4 = indexs_ISCA[3]
featuresIndex_Sonar_ISCA_380iter_run5 = indexs_ISCA[4]
featuresIndex_Sonar_ISCA_380iter_run6 = indexs_ISCA[5]
featuresIndex_Sonar_ISCA_380iter_run7 = indexs_ISCA[6]
featuresIndex_Sonar_ISCA_380iter_run8 = indexs_ISCA[7]
featuresIndex_Sonar_ISCA_380iter_run9 = indexs_ISCA[8]
featuresIndex_Sonar_ISCA_380iter_run10 = indexs_ISCA[9]

# %% [markdown]
# # 100 Iteration (10 Individual Runs)

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_JA_GA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', C=10, gamma=0.5, random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Sonar_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Sonar_100iter.to_csv("./cv10_results_JA_GA_Sonar_100iter.csv")
cv10_results_JA_GA_Sonar_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.6666666666666666  Precision:  0.6666666666666666  Recall:  0.6636363636363636  F1-Score:  0.6636155606407322
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7142857142857143  Precision:  0.75  Recall:  0.7045454545454546  F1-Score:  0.6971153846153846
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7857142857142857  Precision:  0.7860411899313502  Recall:  0.7840909090909092  F1-Score:  0.7846153846153846
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8095238095238095  Precision:  0.8221153846153846  Recall:  0.8045454545454545  F1-Score:  0.8055555555555555
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7380952380952381  Precision:  0.7679045092838197  Recall:  0.7295454545454545  F1-Score:  0.7254901960784315
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_ISSA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISSA_Sonar_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Sonar_100iter.to_csv("./cv10_results_ISSA_Sonar_100iter.csv")
cv10_results_ISSA_Sonar_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7619047619047619  Precision:  0.7638888888888888  Recall:  0.759090909090909  F1-Score:  0.7597254004576658
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6666666666666666  Precision:  0.6706730769230769  Recall:  0.6613636363636364  F1-Score:  0.6597222222222222
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7142857142857143  Precision:  0.7321428571428572  Recall:  0.7068181818181818  F1-Score:  0.7035294117647058
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7857142857142857  Precision:  0.7860411899313502  Recall:  0.7840909090909092  F1-Score:  0.7846153846153846
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.6904761904761905  Precision:  0.7  Recall:  0.6840909090909091  F1-Score:  0.6816326530612244
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_ISCA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISCA_Sonar_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Sonar_100iter.to_csv("./cv10_results_ISCA_Sonar_100iter.csv")
cv10_results_ISCA_Sonar_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.6666666666666666  Precision:  0.6706730769230769  Recall:  0.6613636363636364  F1-Score:  0.6597222222222222
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6428571428571429  Precision:  0.6481481481481481  Recall:  0.6363636363636364  F1-Score:  0.6326530612244898
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.5952380952380952  Precision:  0.5952380952380952  Recall:  0.5954545454545455  F1-Score:  0.5950085082246171
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7142857142857143  Precision:  0.75  Recall:  0.7045454545454546  F1-Score:  0.6971153846153846
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7142857142857143  Precision:  0.7321428571428572  Recall:  0.7068181818181818  F1-Score:  0.7035294117647058
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_Genetic_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Sonar_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Sonar_100iter.to_csv("./cv10_results_Genetic_Sonar_100iter.csv")
cv10_results_Genetic_Sonar_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7380952380952381  Precision:  0.7423529411764705  Recall:  0.7340909090909091  F1-Score:  0.7343300747556067
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7857142857142857  Precision:  0.7860411899313502  Recall:  0.7840909090909092  F1-Score:  0.7846153846153846
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7380952380952381  Precision:  0.7379862700228832  Recall:  0.7363636363636363  F1-Score:  0.7367521367521368
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8095238095238095  Precision:  0.8125  Recall:  0.8068181818181819  F1-Score:  0.8077803203661327
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7380952380952381  Precision:  0.7518518518518519  Recall:  0.7318181818181818  F1-Score:  0.7306122448979592
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_Jaya_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Sonar_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Sonar_100iter.to_csv("./cv10_results_Jaya_Sonar_100iter.csv")
cv10_results_Jaya_Sonar_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7142857142857143  Precision:  0.7152777777777778  Recall:  0.7113636363636364  F1-Score:  0.7116704805491991
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7142857142857143  Precision:  0.7321428571428572  Recall:  0.7068181818181818  F1-Score:  0.7035294117647058
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7142857142857143  Precision:  0.7211538461538461  Recall:  0.7090909090909091  F1-Score:  0.7083333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7142857142857143  Precision:  0.7152777777777778  Recall:  0.7113636363636364  F1-Score:  0.7116704805491991
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7142857142857143  Precision:  0.7159090909090908  Recall:  0.7159090909090908  F1-Score:  0.7142857142857143
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_PSO_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Sonar_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Sonar_100iter.to_csv("./cv10_results_PSO_Sonar_100iter.csv")
cv10_results_PSO_Sonar_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.6904761904761905  Precision:  0.6929411764705883  Recall:  0.6863636363636363  F1-Score:  0.6860264519838988
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7380952380952381  Precision:  0.7518518518518519  Recall:  0.7318181818181818  F1-Score:  0.7306122448979592
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.6666666666666666  Precision:  0.6706730769230769  Recall:  0.6613636363636364  F1-Score:  0.6597222222222222
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6190476190476191  Precision:  0.6201923076923077  Recall:  0.6136363636363636  F1-Score:  0.6111111111111112
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7380952380952381  Precision:  0.7518518518518519  Recall:  0.7318181818181818  F1-Score:  0.7306122448979592
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_MGFPA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Sonar_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Sonar_100iter.to_csv("./cv10_results_MGFPA_Sonar_100iter.csv")
cv10_results_MGFPA_Sonar_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7619047619047619  Precision:  0.7857142857142857  Recall:  0.7545454545454545  F1-Score:  0.7529411764705882
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6904761904761905  Precision:  0.7  Recall:  0.6840909090909091  F1-Score:  0.6816326530612244
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7857142857142857  Precision:  0.8037037037037037  Recall:  0.7795454545454545  F1-Score:  0.7795918367346939
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6666666666666666  Precision:  0.6706730769230769  Recall:  0.6613636363636364  F1-Score:  0.6597222222222222
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8333333333333334  Precision:  0.8411764705882353  Recall:  0.8295454545454546  F1-Score:  0.8309373202990225
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# # 380 Iteration

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_JA_GA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")


av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Sonar_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Sonar_380iter.to_csv("./cv10_results_JA_GA_Sonar_380iter.csv")
cv10_results_JA_GA_Sonar_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.6666666666666666  Precision:  0.6666666666666666  Recall:  0.6636363636363636  F1-Score:  0.6636155606407322
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7142857142857143  Precision:  0.75  Recall:  0.7045454545454546  F1-Score:  0.6971153846153846
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7857142857142857  Precision:  0.7860411899313502  Recall:  0.7840909090909092  F1-Score:  0.7846153846153846
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8095238095238095  Precision:  0.8221153846153846  Recall:  0.8045454545454545  F1-Score:  0.8055555555555555
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7380952380952381  Precision:  0.7679045092838197  Recall:  0.7295454545454545  F1-Score:  0.7254901960784315
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# #### ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_ISSA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISSA_Sonar_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Sonar_380iter.to_csv("./cv10_results_ISSA_Sonar_380iter.csv")
cv10_results_ISSA_Sonar_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7619047619047619  Precision:  0.7638888888888888  Recall:  0.759090909090909  F1-Score:  0.7597254004576658
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6904761904761905  Precision:  0.6929411764705883  Recall:  0.6863636363636363  F1-Score:  0.6860264519838988
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.6904761904761905  Precision:  0.7  Recall:  0.6840909090909091  F1-Score:  0.6816326530612244
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7619047619047619  Precision:  0.7613636363636364  Recall:  0.7613636363636364  F1-Score:  0.7613636363636364
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.6904761904761905  Precision:  0.7  Recall:  0.6840909090909091  F1-Score:  0.6816326530612244
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_ISCA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISCA_Sonar_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Sonar_380iter.to_csv("./cv10_results_ISCA_Sonar_380iter.csv")
cv10_results_ISCA_Sonar_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7142857142857143  Precision:  0.7211538461538461  Recall:  0.7090909090909091  F1-Score:  0.7083333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6428571428571429  Precision:  0.6481481481481481  Recall:  0.6363636363636364  F1-Score:  0.6326530612244898
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.6190476190476191  Precision:  0.6204545454545455  Recall:  0.6204545454545455  F1-Score:  0.6190476190476191
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6904761904761905  Precision:  0.7  Recall:  0.6840909090909091  F1-Score:  0.6816326530612244
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7619047619047619  Precision:  0.7857142857142857  Recall:  0.7545454545454545  F1-Score:  0.7529411764705882
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_Genetic_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Sonar_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Sonar_380iter.to_csv("./cv10_results_Genetic_Sonar_380iter.csv")
cv10_results_Genetic_Sonar_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7142857142857143  Precision:  0.7152777777777778  Recall:  0.7113636363636364  F1-Score:  0.7116704805491991
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7619047619047619  Precision:  0.7857142857142857  Recall:  0.7545454545454545  F1-Score:  0.7529411764705882
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7619047619047619  Precision:  0.7638888888888888  Recall:  0.759090909090909  F1-Score:  0.7597254004576658
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6904761904761905  Precision:  0.6929411764705883  Recall:  0.6863636363636363  F1-Score:  0.6860264519838988
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7380952380952381  Precision:  0.7379862700228832  Recall:  0.7363636363636363  F1-Score:  0.7367521367521368
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_Jaya_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Sonar_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Sonar_380iter.to_csv("./cv10_results_Jaya_Sonar_380iter.csv")
cv10_results_Jaya_Sonar_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.6666666666666666  Precision:  0.6666666666666666  Recall:  0.6636363636363636  F1-Score:  0.6636155606407322
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6904761904761905  Precision:  0.7  Recall:  0.6840909090909091  F1-Score:  0.6816326530612244
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.6666666666666666  Precision:  0.6666666666666666  Recall:  0.6636363636363636  F1-Score:  0.6636155606407322
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6428571428571429  Precision:  0.6481481481481481  Recall:  0.6363636363636364  F1-Score:  0.6326530612244898
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7142857142857143  Precision:  0.7152777777777778  Recall:  0.7113636363636364  F1-Score:  0.7116704805491991
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_PSO_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Sonar_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Sonar_380iter.to_csv("./cv10_results_PSO_Sonar_380iter.csv")
cv10_results_PSO_Sonar_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.6666666666666666  Precision:  0.6706730769230769  Recall:  0.6613636363636364  F1-Score:  0.6597222222222222
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7380952380952381  Precision:  0.7518518518518519  Recall:  0.7318181818181818  F1-Score:  0.7306122448979592
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.6904761904761905  Precision:  0.6929411764705883  Recall:  0.6863636363636363  F1-Score:  0.6860264519838988
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6190476190476191  Precision:  0.6201923076923077  Recall:  0.6136363636363636  F1-Score:  0.6111111111111112
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7380952380952381  Precision:  0.7518518518518519  Recall:  0.7318181818181818  F1-Score:  0.7306122448979592
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Sonar_MGFPA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Sonar[:, var_value_indexes]
    xtest = features_test_Sonar[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Sonar_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Sonar_380iter.to_csv("./cv10_results_MGFPA_Sonar_380iter.csv")
cv10_results_MGFPA_Sonar_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.6904761904761905  Precision:  0.7626262626262625  Recall:  0.6772727272727272  F1-Score:  0.6576802507836992
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6190476190476191  Precision:  0.7083333333333334  Recall:  0.6022727272727273  F1-Score:  0.5543766578249336
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.5952380952380952  Precision:  0.782051282051282  Recall:  0.575  F1-Score:  0.49109052031361367
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6190476190476191  Precision:  0.6691176470588236  Recall:  0.6045454545454545  F1-Score:  0.5714285714285714
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.6428571428571429  Precision:  0.7972972972972974  Recall:  0.625  F1-Score:  0.5728813559322035
# ---------------------------------------------------------
# Run:  6
# ...
