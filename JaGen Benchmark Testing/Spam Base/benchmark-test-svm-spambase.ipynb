# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
from cuml.svm import SVC, SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import seaborn as sns
from sklearn.tree import plot_tree
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")


from sklearn import set_config 

set_config(display="diagram")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
#Genetic
df = pd.read_csv("/kaggle/input/benchmarkjagen/Spambase/Results_Genetic.csv")
df.head(11)
indexs_Genetic = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Genetic.append(np.array(numbers))
        
#ISCA        
df = pd.read_csv("/kaggle/input/benchmarkjagen/Spambase/Results_ISCA.csv")
df.head(11)
indexs_ISCA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISCA.append(np.array(numbers))

#ISSA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Spambase/Results_ISSA.csv")
df.head(11)
indexs_ISSA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISSA.append(np.array(numbers))
        
#JA_GA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Spambase/Results_JA+GA.csv")
df.head(11)
indexs_JA_GA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_JA_GA.append(np.array(numbers))

#Jaya
df = pd.read_csv("/kaggle/input/benchmarkjagen/Spambase/Results_Jaya.csv")
df.head(11)
indexs_Jaya = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Jaya.append(np.array(numbers))

#MGFPA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Spambase/Results_MGFPA.csv")
df.head(11)
indexs_MGFPA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_MGFPA.append(np.array(numbers))

#PSO
df = pd.read_csv("/kaggle/input/benchmarkjagen/Spambase/Results_PSO.csv")
df.head(11)
indexs_PSO = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_PSO.append(np.array(numbers))

# %%
#Original
features_test_Spambase = np.load('/kaggle/input/benchmarkjagen/Spambase/xtest.npy')
y_test = np.load("/kaggle/input/benchmarkjagen/Spambase/ytest.npy")
features_train_Spambase = np.load('/kaggle/input/benchmarkjagen/Spambase/xtrain.npy')
y_train = np.load("/kaggle/input/benchmarkjagen/Spambase/ytrain.npy")
#JA + GA (Jaya + Genetic)
featuresIndex_Spambase_JA_GA_100iter_run1 = indexs_JA_GA[0]
featuresIndex_Spambase_JA_GA_100iter_run2 = indexs_JA_GA[1]
featuresIndex_Spambase_JA_GA_100iter_run3 = indexs_JA_GA[2]
featuresIndex_Spambase_JA_GA_100iter_run4 = indexs_JA_GA[3]
featuresIndex_Spambase_JA_GA_100iter_run5 = indexs_JA_GA[4]
featuresIndex_Spambase_JA_GA_100iter_run6 = indexs_JA_GA[5]
featuresIndex_Spambase_JA_GA_100iter_run7 = indexs_JA_GA[6]
featuresIndex_Spambase_JA_GA_100iter_run8 = indexs_JA_GA[7]
featuresIndex_Spambase_JA_GA_100iter_run9 = indexs_JA_GA[8]
featuresIndex_Spambase_JA_GA_100iter_run10 = indexs_JA_GA[9]

featuresIndex_Spambase_JA_GA_380iter_run1 = indexs_JA_GA[0]
featuresIndex_Spambase_JA_GA_380iter_run2 = indexs_JA_GA[1]
featuresIndex_Spambase_JA_GA_380iter_run3 = indexs_JA_GA[2]
featuresIndex_Spambase_JA_GA_380iter_run4 = indexs_JA_GA[3]
featuresIndex_Spambase_JA_GA_380iter_run5 = indexs_JA_GA[4]
featuresIndex_Spambase_JA_GA_380iter_run6 = indexs_JA_GA[5]
featuresIndex_Spambase_JA_GA_380iter_run7 = indexs_JA_GA[6]
featuresIndex_Spambase_JA_GA_380iter_run8 = indexs_JA_GA[7]
featuresIndex_Spambase_JA_GA_380iter_run9 = indexs_JA_GA[8]
featuresIndex_Spambase_JA_GA_380iter_run10 = indexs_JA_GA[9]

#ISSA
featuresIndex_Spambase_ISSA_100iter_run1 = indexs_ISSA[0]
featuresIndex_Spambase_ISSA_100iter_run2 = indexs_ISSA[1]
featuresIndex_Spambase_ISSA_100iter_run3 = indexs_ISSA[2]
featuresIndex_Spambase_ISSA_100iter_run4 = indexs_ISSA[3]
featuresIndex_Spambase_ISSA_100iter_run5 = indexs_ISSA[4]
featuresIndex_Spambase_ISSA_100iter_run6 = indexs_ISSA[5]
featuresIndex_Spambase_ISSA_100iter_run7 = indexs_ISSA[6]
featuresIndex_Spambase_ISSA_100iter_run8 = indexs_ISSA[7]
featuresIndex_Spambase_ISSA_100iter_run9 = indexs_ISSA[8]
featuresIndex_Spambase_ISSA_100iter_run10 = indexs_ISSA[9]

featuresIndex_Spambase_ISSA_380iter_run1 = indexs_ISSA[0]
featuresIndex_Spambase_ISSA_380iter_run2 = indexs_ISSA[1]
featuresIndex_Spambase_ISSA_380iter_run3 = indexs_ISSA[2]
featuresIndex_Spambase_ISSA_380iter_run4 = indexs_ISSA[3]
featuresIndex_Spambase_ISSA_380iter_run5 = indexs_ISSA[4]
featuresIndex_Spambase_ISSA_380iter_run6 = indexs_ISSA[5]
featuresIndex_Spambase_ISSA_380iter_run7 = indexs_ISSA[6]
featuresIndex_Spambase_ISSA_380iter_run8 = indexs_ISSA[7]
featuresIndex_Spambase_ISSA_380iter_run9 = indexs_ISSA[8]
featuresIndex_Spambase_ISSA_380iter_run10 = indexs_ISSA[9]

#Jaya
featuresIndex_Spambase_Jaya_100iter_run1 = indexs_Jaya[0]
featuresIndex_Spambase_Jaya_100iter_run2 = indexs_Jaya[1]
featuresIndex_Spambase_Jaya_100iter_run3 = indexs_Jaya[2]
featuresIndex_Spambase_Jaya_100iter_run4 = indexs_Jaya[3]
featuresIndex_Spambase_Jaya_100iter_run5 = indexs_Jaya[4]
featuresIndex_Spambase_Jaya_100iter_run6 = indexs_Jaya[5]
featuresIndex_Spambase_Jaya_100iter_run7 = indexs_Jaya[6]
featuresIndex_Spambase_Jaya_100iter_run8 = indexs_Jaya[7]
featuresIndex_Spambase_Jaya_100iter_run9 = indexs_Jaya[8]
featuresIndex_Spambase_Jaya_100iter_run10 = indexs_Jaya[9]

featuresIndex_Spambase_Jaya_380iter_run1 = indexs_Jaya[0]
featuresIndex_Spambase_Jaya_380iter_run2 = indexs_Jaya[1]
featuresIndex_Spambase_Jaya_380iter_run3 = indexs_Jaya[2]
featuresIndex_Spambase_Jaya_380iter_run4 = indexs_Jaya[3]
featuresIndex_Spambase_Jaya_380iter_run5 = indexs_Jaya[4]
featuresIndex_Spambase_Jaya_380iter_run6 = indexs_Jaya[5]
featuresIndex_Spambase_Jaya_380iter_run7 = indexs_Jaya[6]
featuresIndex_Spambase_Jaya_380iter_run8 = indexs_Jaya[7]
featuresIndex_Spambase_Jaya_380iter_run9 = indexs_Jaya[8]
featuresIndex_Spambase_Jaya_380iter_run10 = indexs_Jaya[9]

#PSO
featuresIndex_Spambase_PSO_100iter_run1 = indexs_PSO[0]
featuresIndex_Spambase_PSO_100iter_run2 = indexs_PSO[1]
featuresIndex_Spambase_PSO_100iter_run3 = indexs_PSO[2]
featuresIndex_Spambase_PSO_100iter_run4 = indexs_PSO[3]
featuresIndex_Spambase_PSO_100iter_run5 = indexs_PSO[4]
featuresIndex_Spambase_PSO_100iter_run6 = indexs_PSO[5]
featuresIndex_Spambase_PSO_100iter_run7 = indexs_PSO[6]
featuresIndex_Spambase_PSO_100iter_run8 = indexs_PSO[7]
featuresIndex_Spambase_PSO_100iter_run9 = indexs_PSO[8]
featuresIndex_Spambase_PSO_100iter_run10 = indexs_PSO[9]

featuresIndex_Spambase_PSO_380iter_run1 = indexs_PSO[0]
featuresIndex_Spambase_PSO_380iter_run2 = indexs_PSO[1]
featuresIndex_Spambase_PSO_380iter_run3 = indexs_PSO[2]
featuresIndex_Spambase_PSO_380iter_run4 = indexs_PSO[3]
featuresIndex_Spambase_PSO_380iter_run5 = indexs_PSO[4]
featuresIndex_Spambase_PSO_380iter_run6 = indexs_PSO[5]
featuresIndex_Spambase_PSO_380iter_run7 = indexs_PSO[6]
featuresIndex_Spambase_PSO_380iter_run8 = indexs_PSO[7]
featuresIndex_Spambase_PSO_380iter_run9 = indexs_PSO[8]
featuresIndex_Spambase_PSO_380iter_run10 = indexs_PSO[9]

#MGFPA
featuresIndex_Spambase_MGFPA_100iter_run1 = indexs_MGFPA[0]
featuresIndex_Spambase_MGFPA_100iter_run2 = indexs_MGFPA[1]
featuresIndex_Spambase_MGFPA_100iter_run3 = indexs_MGFPA[2]
featuresIndex_Spambase_MGFPA_100iter_run4 = indexs_MGFPA[3]
featuresIndex_Spambase_MGFPA_100iter_run5 = indexs_MGFPA[4]
featuresIndex_Spambase_MGFPA_100iter_run6 = indexs_MGFPA[5]
featuresIndex_Spambase_MGFPA_100iter_run7 = indexs_MGFPA[6]
featuresIndex_Spambase_MGFPA_100iter_run8 = indexs_MGFPA[7]
featuresIndex_Spambase_MGFPA_100iter_run9 = indexs_MGFPA[8]
featuresIndex_Spambase_MGFPA_100iter_run10 = indexs_MGFPA[9]

featuresIndex_Spambase_MGFPA_380iter_run1 = indexs_MGFPA[0]
featuresIndex_Spambase_MGFPA_380iter_run2 = indexs_MGFPA[1]
featuresIndex_Spambase_MGFPA_380iter_run3 = indexs_MGFPA[2]
featuresIndex_Spambase_MGFPA_380iter_run4 = indexs_MGFPA[3]
featuresIndex_Spambase_MGFPA_380iter_run5 = indexs_MGFPA[4]
featuresIndex_Spambase_MGFPA_380iter_run6 = indexs_MGFPA[5]
featuresIndex_Spambase_MGFPA_380iter_run7 = indexs_MGFPA[6]
featuresIndex_Spambase_MGFPA_380iter_run8 = indexs_MGFPA[7]
featuresIndex_Spambase_MGFPA_380iter_run9 = indexs_MGFPA[8]
featuresIndex_Spambase_MGFPA_380iter_run10 = indexs_MGFPA[9]

#Genetic
featuresIndex_Spambase_Genetic_100iter_run1 = indexs_Genetic[0]
featuresIndex_Spambase_Genetic_100iter_run2 = indexs_Genetic[1]
featuresIndex_Spambase_Genetic_100iter_run3 = indexs_Genetic[2]
featuresIndex_Spambase_Genetic_100iter_run4 = indexs_Genetic[3]
featuresIndex_Spambase_Genetic_100iter_run5 = indexs_Genetic[4]
featuresIndex_Spambase_Genetic_100iter_run6 = indexs_Genetic[5]
featuresIndex_Spambase_Genetic_100iter_run7 = indexs_Genetic[6]
featuresIndex_Spambase_Genetic_100iter_run8 = indexs_Genetic[7]
featuresIndex_Spambase_Genetic_100iter_run9 = indexs_Genetic[8]
featuresIndex_Spambase_Genetic_100iter_run10 = indexs_Genetic[9]

featuresIndex_Spambase_Genetic_380iter_run1 = indexs_Genetic[0]
featuresIndex_Spambase_Genetic_380iter_run2 = indexs_Genetic[1]
featuresIndex_Spambase_Genetic_380iter_run3 = indexs_Genetic[2]
featuresIndex_Spambase_Genetic_380iter_run4 = indexs_Genetic[3]
featuresIndex_Spambase_Genetic_380iter_run5 = indexs_Genetic[4]
featuresIndex_Spambase_Genetic_380iter_run6 = indexs_Genetic[5]
featuresIndex_Spambase_Genetic_380iter_run7 = indexs_Genetic[6]
featuresIndex_Spambase_Genetic_380iter_run8 = indexs_Genetic[7]
featuresIndex_Spambase_Genetic_380iter_run9 = indexs_Genetic[8]
featuresIndex_Spambase_Genetic_380iter_run10 = indexs_Genetic[9]

#ISCA
featuresIndex_Spambase_ISCA_100iter_run1 = indexs_ISCA[0]
featuresIndex_Spambase_ISCA_100iter_run2 = indexs_ISCA[1]
featuresIndex_Spambase_ISCA_100iter_run3 = indexs_ISCA[2]
featuresIndex_Spambase_ISCA_100iter_run4 = indexs_ISCA[3]
featuresIndex_Spambase_ISCA_100iter_run5 = indexs_ISCA[4]
featuresIndex_Spambase_ISCA_100iter_run6 = indexs_ISCA[5]
featuresIndex_Spambase_ISCA_100iter_run7 = indexs_ISCA[6]
featuresIndex_Spambase_ISCA_100iter_run8 = indexs_ISCA[7]
featuresIndex_Spambase_ISCA_100iter_run9 = indexs_ISCA[8]
featuresIndex_Spambase_ISCA_100iter_run10 = indexs_ISCA[9]

featuresIndex_Spambase_ISCA_380iter_run1 = indexs_ISCA[0]
featuresIndex_Spambase_ISCA_380iter_run2 = indexs_ISCA[1]
featuresIndex_Spambase_ISCA_380iter_run3 = indexs_ISCA[2]
featuresIndex_Spambase_ISCA_380iter_run4 = indexs_ISCA[3]
featuresIndex_Spambase_ISCA_380iter_run5 = indexs_ISCA[4]
featuresIndex_Spambase_ISCA_380iter_run6 = indexs_ISCA[5]
featuresIndex_Spambase_ISCA_380iter_run7 = indexs_ISCA[6]
featuresIndex_Spambase_ISCA_380iter_run8 = indexs_ISCA[7]
featuresIndex_Spambase_ISCA_380iter_run9 = indexs_ISCA[8]
featuresIndex_Spambase_ISCA_380iter_run10 = indexs_ISCA[9]

# %% [markdown]
# # 100 Iteration (10 Individual Runs)

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Spambase_JA_GA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Spambase[:, var_value_indexes]
    xtest = features_test_Spambase[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Spambase_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Spambase_100iter.to_csv("./cv10_results_JA_GA_Spambase_100iter.csv")
cv10_results_JA_GA_Spambase_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.9077090119435396  Precision:  0.9045167544993538  Recall:  0.9016928818981604  F1-Score:  0.9030450672931758
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9131378935939196  Precision:  0.9116381469533332  Recall:  0.9056918155158624  F1-Score:  0.9084219946306056
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9044516829533116  Precision:  0.9016254039819654  Recall:  0.8975606504932018  F1-Score:  0.8994711094793454
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9174809989142236  Precision:  0.9167026478827983  Recall:  0.9097573980271928  F1-Score:  0.9129099686457971
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8946796959826275  Precision:  0.8930539881504171  Recall:  0.8851639562783258  F1-Score:  0.8886690053523918
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_