# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
from cuml.svm import SVC, SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import seaborn as sns
from sklearn.tree import plot_tree
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")


from sklearn import set_config 

set_config(display="diagram")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
#Genetic
df = pd.read_csv("/kaggle/input/benchmarkjagen/tic-tac-toe/Results_Genetic.csv")
df.head(11)
indexs_Genetic = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Genetic.append(np.array(numbers))
        
#ISCA        
df = pd.read_csv("/kaggle/input/benchmarkjagen/tic-tac-toe/Results_ISCA.csv")
df.head(11)
indexs_ISCA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISCA.append(np.array(numbers))

#ISSA
df = pd.read_csv("/kaggle/input/benchmarkjagen/tic-tac-toe/Results_ISSA.csv")
df.head(11)
indexs_ISSA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISSA.append(np.array(numbers))
        
#JA_GA
df = pd.read_csv("/kaggle/input/benchmarkjagen/tic-tac-toe/Results_JA+GA.csv")
df.head(11)
indexs_JA_GA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_JA_GA.append(np.array(numbers))

#Jaya
df = pd.read_csv("/kaggle/input/benchmarkjagen/tic-tac-toe/Results_Jaya.csv")
df.head(11)
indexs_Jaya = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Jaya.append(np.array(numbers))

#MGFPA
df = pd.read_csv("/kaggle/input/benchmarkjagen/tic-tac-toe/Results_MGFPA.csv")
df.head(11)
indexs_MGFPA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_MGFPA.append(np.array(numbers))

#PSO
df = pd.read_csv("/kaggle/input/benchmarkjagen/tic-tac-toe/Results_PSO.csv")
df.head(11)
indexs_PSO = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_PSO.append(np.array(numbers))

# %%
#Original
features_test_tic-tac-toe = np.load('/kaggle/input/benchmarkjagen/tic-tac-toe/xtest.npy')
y_test = np.load("/kaggle/input/benchmarkjagen/tic-tac-toe/ytest.npy")
features_train_tic-tac-toe = np.load('/kaggle/input/benchmarkjagen/tic-tac-toe/xtrain.npy')
y_train = np.load("/kaggle/input/benchmarkjagen/tic-tac-toe/ytrain.npy")
#JA + GA (Jaya + Genetic)
featuresIndex_tic-tac-toe_JA_GA_100iter_run1 = indexs_JA_GA[0]
featuresIndex_tic-tac-toe_JA_GA_100iter_run2 = indexs_JA_GA[1]
featuresIndex_tic-tac-toe_JA_GA_100iter_run3 = indexs_JA_GA[2]
featuresIndex_tic-tac-toe_JA_GA_100iter_run4 = indexs_JA_GA[3]
featuresIndex_tic-tac-toe_JA_GA_100iter_run5 = indexs_JA_GA[4]
featuresIndex_tic-tac-toe_JA_GA_100iter_run6 = indexs_JA_GA[5]
featuresIndex_tic-tac-toe_JA_GA_100iter_run7 = indexs_JA_GA[6]
featuresIndex_tic-tac-toe_JA_GA_100iter_run8 = indexs_JA_GA[7]
featuresIndex_tic-tac-toe_JA_GA_100iter_run9 = indexs_JA_GA[8]
featuresIndex_tic-tac-toe_JA_GA_100iter_run10 = indexs_JA_GA[9]

featuresIndex_tic-tac-toe_JA_GA_380iter_run1 = indexs_JA_GA[0]
featuresIndex_tic-tac-toe_JA_GA_380iter_run2 = indexs_JA_GA[1]
featuresIndex_tic-tac-toe_JA_GA_380iter_run3 = indexs_JA_GA[2]
featuresIndex_tic-tac-toe_JA_GA_380iter_run4 = indexs_JA_GA[3]
featuresIndex_tic-tac-toe_JA_GA_380iter_run5 = indexs_JA_GA[4]
featuresIndex_tic-tac-toe_JA_GA_380iter_run6 = indexs_JA_GA[5]
featuresIndex_tic-tac-toe_JA_GA_380iter_run7 = indexs_JA_GA[6]
featuresIndex_tic-tac-toe_JA_GA_380iter_run8 = indexs_JA_GA[7]
featuresIndex_tic-tac-toe_JA_GA_380iter_run9 = indexs_JA_GA[8]
featuresIndex_tic-tac-toe_JA_GA_380iter_run10 = indexs_JA_GA[9]

#ISSA
featuresIndex_tic-tac-toe_ISSA_100iter_run1 = indexs_ISSA[0]
featuresIndex_tic-tac-toe_ISSA_100iter_run2 = indexs_ISSA[1]
featuresIndex_tic-tac-toe_ISSA_100iter_run3 = indexs_ISSA[2]
featuresIndex_tic-tac-toe_ISSA_100iter_run4 = indexs_ISSA[3]
featuresIndex_tic-tac-toe_ISSA_100iter_run5 = indexs_ISSA[4]
featuresIndex_tic-tac-toe_ISSA_100iter_run6 = indexs_ISSA[5]
featuresIndex_tic-tac-toe_ISSA_100iter_run7 = indexs_ISSA[6]
featuresIndex_tic-tac-toe_ISSA_100iter_run8 = indexs_ISSA[7]
featuresIndex_tic-tac-toe_ISSA_100iter_run9 = indexs_ISSA[8]
featuresIndex_tic-tac-toe_ISSA_100iter_run10 = indexs_ISSA[9]

featuresIndex_tic-tac-toe_ISSA_380iter_run1 = indexs_ISSA[0]
featuresIndex_tic-tac-toe_ISSA_380iter_run2 = indexs_ISSA[1]
featuresIndex_tic-tac-toe_ISSA_380iter_run3 = indexs_ISSA[2]
featuresIndex_tic-tac-toe_ISSA_380iter_run4 = indexs_ISSA[3]
featuresIndex_tic-tac-toe_ISSA_380iter_run5 = indexs_ISSA[4]
featuresIndex_tic-tac-toe_ISSA_380iter_run6 = indexs_ISSA[5]
featuresIndex_tic-tac-toe_ISSA_380iter_run7 = indexs_ISSA[6]
featuresIndex_tic-tac-toe_ISSA_380iter_run8 = indexs_ISSA[7]
featuresIndex_tic-tac-toe_ISSA_380iter_run9 = indexs_ISSA[8]
featuresIndex_tic-tac-toe_ISSA_380iter_run10 = indexs_ISSA[9]

#Jaya
featuresIndex_tic-tac-toe_Jaya_100iter_run1 = indexs_Jaya[0]
featuresIndex_tic-tac-toe_Jaya_100iter_run2 = indexs_Jaya[1]
featuresIndex_tic-tac-toe_Jaya_100iter_run3 = indexs_Jaya[2]
featuresIndex_tic-tac-toe_Jaya_100iter_run4 = indexs_Jaya[3]
featuresIndex_tic-tac-toe_Jaya_100iter_run5 = indexs_Jaya[4]
featuresIndex_tic-tac-toe_Jaya_100iter_run6 = indexs_Jaya[5]
featuresIndex_tic-tac-toe_Jaya_100iter_run7 = indexs_Jaya[6]
featuresIndex_tic-tac-toe_Jaya_100iter_run8 = indexs_Jaya[7]
featuresIndex_tic-tac-toe_Jaya_100iter_run9 = indexs_Jaya[8]
featuresIndex_tic-tac-toe_Jaya_100iter_run10 = indexs_Jaya[9]

featuresIndex_tic-tac-toe_Jaya_380iter_run1 = indexs_Jaya[0]
featuresIndex_tic-tac-toe_Jaya_380iter_run2 = indexs_Jaya[1]
featuresIndex_tic-tac-toe_Jaya_380iter_run3 = indexs_Jaya[2]
featuresIndex_tic-tac-toe_Jaya_380iter_run4 = indexs_Jaya[3]
featuresIndex_tic-tac-toe_Jaya_380iter_run5 = indexs_Jaya[4]
featuresIndex_tic-tac-toe_Jaya_380iter_run6 = indexs_Jaya[5]
featuresIndex_tic-tac-toe_Jaya_380iter_run7 = indexs_Jaya[6]
featuresIndex_tic-tac-toe_Jaya_380iter_run8 = indexs_Jaya[7]
featuresIndex_tic-tac-toe_Jaya_380iter_run9 = indexs_Jaya[8]
featuresIndex_tic-tac-toe_Jaya_380iter_run10 = indexs_Jaya[9]

#PSO
featuresIndex_tic-tac-toe_PSO_100iter_run1 = indexs_PSO[0]
featuresIndex_tic-tac-toe_PSO_100iter_run2 = indexs_PSO[1]
featuresIndex_tic-tac-toe_PSO_100iter_run3 = indexs_PSO[2]
featuresIndex_tic-tac-toe_PSO_100iter_run4 = indexs_PSO[3]
featuresIndex_tic-tac-toe_PSO_100iter_run5 = indexs_PSO[4]
featuresIndex_tic-tac-toe_PSO_100iter_run6 = indexs_PSO[5]
featuresIndex_tic-tac-toe_PSO_100iter_run7 = indexs_PSO[6]
featuresIndex_tic-tac-toe_PSO_100iter_run8 = indexs_PSO[7]
featuresIndex_tic-tac-toe_PSO_100iter_run9 = indexs_PSO[8]
featuresIndex_tic-tac-toe_PSO_100iter_run10 = indexs_PSO[9]

featuresIndex_tic-tac-toe_PSO_380iter_run1 = indexs_PSO[0]
featuresIndex_tic-tac-toe_PSO_380iter_run2 = indexs_PSO[1]
featuresIndex_tic-tac-toe_PSO_380iter_run3 = indexs_PSO[2]
featuresIndex_tic-tac-toe_PSO_380iter_run4 = indexs_PSO[3]
featuresIndex_tic-tac-toe_PSO_380iter_run5 = indexs_PSO[4]
featuresIndex_tic-tac-toe_PSO_380iter_run6 = indexs_PSO[5]
featuresIndex_tic-tac-toe_PSO_380iter_run7 = indexs_PSO[6]
featuresIndex_tic-tac-toe_PSO_380iter_run8 = indexs_PSO[7]
featuresIndex_tic-tac-toe_PSO_380iter_run9 = indexs_PSO[8]
featuresIndex_tic-tac-toe_PSO_380iter_run10 = indexs_PSO[9]

#MGFPA
featuresIndex_tic-tac-toe_MGFPA_100iter_run1 = indexs_MGFPA[0]
featuresIndex_tic-tac-toe_MGFPA_100iter_run2 = indexs_MGFPA[1]
featuresIndex_tic-tac-toe_MGFPA_100iter_run3 = indexs_MGFPA[2]
featuresIndex_tic-tac-toe_MGFPA_100iter_run4 = indexs_MGFPA[3]
featuresIndex_tic-tac-toe_MGFPA_100iter_run5 = indexs_MGFPA[4]
featuresIndex_tic-tac-toe_MGFPA_100iter_run6 = indexs_MGFPA[5]
featuresIndex_tic-tac-toe_MGFPA_100iter_run7 = indexs_MGFPA[6]
featuresIndex_tic-tac-toe_MGFPA_100iter_run8 = indexs_MGFPA[7]
featuresIndex_tic-tac-toe_MGFPA_100iter_run9 = indexs_MGFPA[8]
featuresIndex_tic-tac-toe_MGFPA_100iter_run10 = indexs_MGFPA[9]

featuresIndex_tic-tac-toe_MGFPA_380iter_run1 = indexs_MGFPA[0]
featuresIndex_tic-tac-toe_MGFPA_380iter_run2 = indexs_MGFPA[1]
featuresIndex_tic-tac-toe_MGFPA_380iter_run3 = indexs_MGFPA[2]
featuresIndex_tic-tac-toe_MGFPA_380iter_run4 = indexs_MGFPA[3]
featuresIndex_tic-tac-toe_MGFPA_380iter_run5 = indexs_MGFPA[4]
featuresIndex_tic-tac-toe_MGFPA_380iter_run6 = indexs_MGFPA[5]
featuresIndex_tic-tac-toe_MGFPA_380iter_run7 = indexs_MGFPA[6]
featuresIndex_tic-tac-toe_MGFPA_380iter_run8 = indexs_MGFPA[7]
featuresIndex_tic-tac-toe_MGFPA_380iter_run9 = indexs_MGFPA[8]
featuresIndex_tic-tac-toe_MGFPA_380iter_run10 = indexs_MGFPA[9]

#Genetic
featuresIndex_tic-tac-toe_Genetic_100iter_run1 = indexs_Genetic[0]
featuresIndex_tic-tac-toe_Genetic_100iter_run2 = indexs_Genetic[1]
featuresIndex_tic-tac-toe_Genetic_100iter_run3 = indexs_Genetic[2]
featuresIndex_tic-tac-toe_Genetic_100iter_run4 = indexs_Genetic[3]
featuresIndex_tic-tac-toe_Genetic_100iter_run5 = indexs_Genetic[4]
featuresIndex_tic-tac-toe_Genetic_100iter_run6 = indexs_Genetic[5]
featuresIndex_tic-tac-toe_Genetic_100iter_run7 = indexs_Genetic[6]
featuresIndex_tic-tac-toe_Genetic_100iter_run8 = indexs_Genetic[7]
featuresIndex_tic-tac-toe_Genetic_100iter_run9 = indexs_Genetic[8]
featuresIndex_tic-tac-toe_Genetic_100iter_run10 = indexs_Genetic[9]

featuresIndex_tic-tac-toe_Genetic_380iter_run1 = indexs_Genetic[0]
featuresIndex_tic-tac-toe_Genetic_380iter_run2 = indexs_Genetic[1]
featuresIndex_tic-tac-toe_Genetic_380iter_run3 = indexs_Genetic[2]
featuresIndex_tic-tac-toe_Genetic_380iter_run4 = indexs_Genetic[3]
featuresIndex_tic-tac-toe_Genetic_380iter_run5 = indexs_Genetic[4]
featuresIndex_tic-tac-toe_Genetic_380iter_run6 = indexs_Genetic[5]
featuresIndex_tic-tac-toe_Genetic_380iter_run7 = indexs_Genetic[6]
featuresIndex_tic-tac-toe_Genetic_380iter_run8 = indexs_Genetic[7]
featuresIndex_tic-tac-toe_Genetic_380iter_run9 = indexs_Genetic[8]
featuresIndex_tic-tac-toe_Genetic_380iter_run10 = indexs_Genetic[9]

#ISCA
featuresIndex_tic-tac-toe_ISCA_100iter_run1 = indexs_ISCA[0]
featuresIndex_tic-tac-toe_ISCA_100iter_run2 = indexs_ISCA[1]
featuresIndex_tic-tac-toe_ISCA_100iter_run3 = indexs_ISCA[2]
featuresIndex_tic-tac-toe_ISCA_100iter_run4 = indexs_ISCA[3]
featuresIndex_tic-tac-toe_ISCA_100iter_run5 = indexs_ISCA[4]
featuresIndex_tic-tac-toe_ISCA_100iter_run6 = indexs_ISCA[5]
featuresIndex_tic-tac-toe_ISCA_100iter_run7 = indexs_ISCA[6]
featuresIndex_tic-tac-toe_ISCA_100iter_run8 = indexs_ISCA[7]
featuresIndex_tic-tac-toe_ISCA_100iter_run9 = indexs_ISCA[8]
featuresIndex_tic-tac-toe_ISCA_100iter_run10 = indexs_ISCA[9]

featuresIndex_tic-tac-toe_ISCA_380iter_run1 = indexs_ISCA[0]
featuresIndex_tic-tac-toe_ISCA_380iter_run2 = indexs_ISCA[1]
featuresIndex_tic-tac-toe_ISCA_380iter_run3 = indexs_ISCA[2]
featuresIndex_tic-tac-toe_ISCA_380iter_run4 = indexs_ISCA[3]
featuresIndex_tic-tac-toe_ISCA_380iter_run5 = indexs_ISCA[4]
featuresIndex_tic-tac-toe_ISCA_380iter_run6 = indexs_ISCA[5]
featuresIndex_tic-tac-toe_ISCA_380iter_run7 = indexs_ISCA[6]
featuresIndex_tic-tac-toe_ISCA_380iter_run8 = indexs_ISCA[7]
featuresIndex_tic-tac-toe_ISCA_380iter_run9 = indexs_ISCA[8]
featuresIndex_tic-tac-toe_ISCA_380iter_run10 = indexs_ISCA[9]

# %% [markdown]
# # 100 Iteration (10 Individual Runs)

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_JA_GA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_tic-tac-toe_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_tic-tac-toe_100iter.to_csv("./cv10_results_JA_GA_tic-tac-toe_100iter.csv")
cv10_results_JA_GA_tic-tac-toe_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7864583333333334  Precision:  0.7851399642644432  Recall:  0.7286567164179105  F1-Score:  0.7429383143388956
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7604166666666666  Precision:  0.7588434824745598  Recall:  0.6913432835820896  F1-Score:  0.7037037037037037
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7864583333333334  Precision:  0.7851399642644432  Recall:  0.7286567164179105  F1-Score:  0.7429383143388956
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9895833333333334  Precision:  0.9921259842519685  Recall:  0.9850746268656716  F1-Score:  0.9884559884559885
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9895833333333334  Precision:  0.9921259842519685  Recall:  0.9850746268656716  F1-Score:  0.9884559884559885
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_ISSA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISSA_tic-tac-toe_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_tic-tac-toe_100iter.to_csv("./cv10_results_ISSA_tic-tac-toe_100iter.csv")
cv10_results_ISSA_tic-tac-toe_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7864583333333334  Precision:  0.764943074003795  Recall:  0.7667462686567164  F1-Score:  0.7658188308790719
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7864583333333334  Precision:  0.764943074003795  Recall:  0.7667462686567164  F1-Score:  0.7658188308790719
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7864583333333334  Precision:  0.764943074003795  Recall:  0.7667462686567164  F1-Score:  0.7658188308790719
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7864583333333334  Precision:  0.764943074003795  Recall:  0.7667462686567164  F1-Score:  0.7658188308790719
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7864583333333334  Precision:  0.764943074003795  Recall:  0.7667462686567164  F1-Score:  0.7658188308790719
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_ISCA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISCA_tic-tac-toe_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_tic-tac-toe_100iter.to_csv("./cv10_results_ISCA_tic-tac-toe_100iter.csv")
cv10_results_ISCA_tic-tac-toe_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7864583333333334  Precision:  0.764943074003795  Recall:  0.7667462686567164  F1-Score:  0.7658188308790719
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7864583333333334  Precision:  0.764943074003795  Recall:  0.7667462686567164  F1-Score:  0.7658188308790719
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7864583333333334  Precision:  0.764943074003795  Recall:  0.7667462686567164  F1-Score:  0.7658188308790719
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7864583333333334  Precision:  0.764943074003795  Recall:  0.7667462686567164  F1-Score:  0.7658188308790719
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7604166666666666  Precision:  0.7371668024676987  Recall:  0.7432835820895523  F1-Score:  0.7398373983739838
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_Genetic_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_tic-tac-toe_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_tic-tac-toe_100iter.to_csv("./cv10_results_Genetic_tic-tac-toe_100iter.csv")
cv10_results_Genetic_tic-tac-toe_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.78125  Precision:  0.7760821716801174  Recall:  0.7246567164179105  F1-Score:  0.7380116959064327
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9895833333333334  Precision:  0.9921259842519685  Recall:  0.9850746268656716  F1-Score:  0.9884559884559885
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9895833333333334  Precision:  0.9921259842519685  Recall:  0.9850746268656716  F1-Score:  0.9884559884559885
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.78125  Precision:  0.7760821716801174  Recall:  0.7246567164179105  F1-Score:  0.7380116959064327
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9895833333333334  Precision:  0.9921259842519685  Recall:  0.9850746268656716  F1-Score:  0.9884559884559885
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_Jaya_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_tic-tac-toe_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_tic-tac-toe_100iter.to_csv("./cv10_results_Jaya_tic-tac-toe_100iter.csv")
cv10_results_Jaya_tic-tac-toe_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9791666666666666  Precision:  0.9844961240310077  Recall:  0.9701492537313433  F1-Score:  0.9767413688673531
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9791666666666666  Precision:  0.9844961240310077  Recall:  0.9701492537313433  F1-Score:  0.9767413688673531
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.703125  Precision:  0.6696428571428572  Recall:  0.6542686567164179  F1-Score:  0.6590972806279787
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_PSO_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_tic-tac-toe_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_tic-tac-toe_100iter.to_csv("./cv10_results_PSO_tic-tac-toe_100iter.csv")
cv10_results_PSO_tic-tac-toe_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9791666666666666  Precision:  0.9844961240310077  Recall:  0.9701492537313433  F1-Score:  0.9767413688673531
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_MGFPA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_tic-tac-toe_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_tic-tac-toe_100iter.to_csv("./cv10_results_MGFPA_tic-tac-toe_100iter.csv")
cv10_results_MGFPA_tic-tac-toe_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8333333333333334  Precision:  0.8864864864864865  Recall:  0.7646567164179104  F1-Score:  0.7890109890109891
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# # 380 Iteration

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_JA_GA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")


av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_tic-tac-toe_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_tic-tac-toe_380iter.to_csv("./cv10_results_JA_GA_tic-tac-toe_380iter.csv")
cv10_results_JA_GA_tic-tac-toe_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7864583333333334  Precision:  0.7851399642644432  Recall:  0.7286567164179105  F1-Score:  0.7429383143388956
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7604166666666666  Precision:  0.7588434824745598  Recall:  0.6913432835820896  F1-Score:  0.7037037037037037
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7864583333333334  Precision:  0.7851399642644432  Recall:  0.7286567164179105  F1-Score:  0.7429383143388956
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9895833333333334  Precision:  0.9921259842519685  Recall:  0.9850746268656716  F1-Score:  0.9884559884559885
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9895833333333334  Precision:  0.9921259842519685  Recall:  0.9850746268656716  F1-Score:  0.9884559884559885
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_ISSA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISSA_tic-tac-toe_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_tic-tac-toe_380iter.to_csv("./cv10_results_ISSA_tic-tac-toe_380iter.csv")
cv10_results_ISSA_tic-tac-toe_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_ISCA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISCA_tic-tac-toe_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_tic-tac-toe_380iter.to_csv("./cv10_results_ISCA_tic-tac-toe_380iter.csv")
cv10_results_ISCA_tic-tac-toe_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.765625  Precision:  0.7425558312655087  Recall:  0.7334328358208955  F1-Score:  0.7373461012311902
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_Genetic_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_tic-tac-toe_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_tic-tac-toe_380iter.to_csv("./cv10_results_Genetic_tic-tac-toe_380iter.csv")
cv10_results_Genetic_tic-tac-toe_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7760416666666666  Precision:  0.7535578747628084  Recall:  0.7552835820895523  F1-Score:  0.7543953592146363
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.9479166666666666  Precision:  0.9576908372626481  Recall:  0.9288358208955223  F1-Score:  0.94093761535622
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9479166666666666  Precision:  0.9576908372626481  Recall:  0.9288358208955223  F1-Score:  0.94093761535622
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7760416666666666  Precision:  0.7535578747628084  Recall:  0.7552835820895523  F1-Score:  0.7543953592146363
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.9479166666666666  Precision:  0.9576908372626481  Recall:  0.9288358208955223  F1-Score:  0.94093761535622
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_Jaya_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_tic-tac-toe_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_tic-tac-toe_380iter.to_csv("./cv10_results_Jaya_tic-tac-toe_380iter.csv")
cv10_results_Jaya_tic-tac-toe_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7708333333333334  Precision:  0.7482465854558877  Recall:  0.7408955223880597  F1-Score:  0.7441550575408842
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.9791666666666666  Precision:  0.9844961240310077  Recall:  0.9701492537313433  F1-Score:  0.9767413688673531
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.9791666666666666  Precision:  0.9844961240310077  Recall:  0.9701492537313433  F1-Score:  0.9767413688673531
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.703125  Precision:  0.6696428571428572  Recall:  0.6542686567164179  F1-Score:  0.6590972806279787
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_PSO_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_tic-tac-toe_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_tic-tac-toe_380iter.to_csv("./cv10_results_PSO_tic-tac-toe_380iter.csv")
cv10_results_PSO_tic-tac-toe_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8333333333333334  Precision:  0.8864864864864865  Recall:  0.7646567164179104  F1-Score:  0.7890109890109891
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_tic-tac-toe_MGFPA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_tic-tac-toe[:, var_value_indexes]
    xtest = features_test_tic-tac-toe[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_tic-tac-toe_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_tic-tac-toe_380iter.to_csv("./cv10_results_MGFPA_tic-tac-toe_380iter.csv")
cv10_results_MGFPA_tic-tac-toe_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7864583333333334  Precision:  0.7651515151515151  Recall:  0.7632835820895523  F1-Score:  0.7641913548812269
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.875  Precision:  0.9106575963718821  Recall:  0.8243582089552239  F1-Score:  0.8487394957983194
# ---------------------------------------------------------
# Run:  6
# ...
