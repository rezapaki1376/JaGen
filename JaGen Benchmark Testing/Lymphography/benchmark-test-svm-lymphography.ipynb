# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
from cuml.svm import SVC, SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import seaborn as sns
from sklearn.tree import plot_tree
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")


from sklearn import set_config 

set_config(display="diagram")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
#Genetic
df = pd.read_csv("/kaggle/input/benchmarkjagen/lymphography/Results_Genetic.csv")
df.head(11)
indexs_Genetic = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Genetic.append(np.array(numbers))

#ISSA
df = pd.read_csv("/kaggle/input/benchmarkjagen/lymphography/Results_ISSA.csv")
df.head(11)
indexs_ISSA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISSA.append(np.array(numbers))
        
#JA_GA
df = pd.read_csv("/kaggle/input/benchmarkjagen/lymphography/Results_JA+GA.csv")
df.head(11)
indexs_JA_GA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_JA_GA.append(np.array(numbers))

#Jaya
df = pd.read_csv("/kaggle/input/benchmarkjagen/lymphography/Results_Jaya.csv")
df.head(11)
indexs_Jaya = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Jaya.append(np.array(numbers))
        
#MGFPA
df = pd.read_csv("/kaggle/input/benchmarkjagen/lymphography/Results_MGFPA.csv")
df.head(11)
indexs_MGFPA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_MGFPA.append(np.array(numbers))

#PSO
df = pd.read_csv("/kaggle/input/benchmarkjagen/lymphography/Results_PSO.csv")
df.head(11)
indexs_PSO = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_PSO.append(np.array(numbers))

# %%
#Original
features_test_lymphography = np.load('/kaggle/input/benchmarkjagen/lymphography/xtest.npy')
y_test = np.load("/kaggle/input/benchmarkjagen/lymphography/ytest.npy")
features_train_lymphography = np.load('/kaggle/input/benchmarkjagen/lymphography/xtrain.npy')
y_train = np.load("/kaggle/input/benchmarkjagen/lymphography/ytrain.npy")
#JA + GA (Jaya + Genetic)
featuresIndex_lymphography_JA_GA_100iter_run1 = indexs_JA_GA[0]
featuresIndex_lymphography_JA_GA_100iter_run2 = indexs_JA_GA[1]
featuresIndex_lymphography_JA_GA_100iter_run3 = indexs_JA_GA[2]
featuresIndex_lymphography_JA_GA_100iter_run4 = indexs_JA_GA[3]
featuresIndex_lymphography_JA_GA_100iter_run5 = indexs_JA_GA[4]
featuresIndex_lymphography_JA_GA_100iter_run6 = indexs_JA_GA[5]
featuresIndex_lymphography_JA_GA_100iter_run7 = indexs_JA_GA[6]
featuresIndex_lymphography_JA_GA_100iter_run8 = indexs_JA_GA[7]
featuresIndex_lymphography_JA_GA_100iter_run9 = indexs_JA_GA[8]
featuresIndex_lymphography_JA_GA_100iter_run10 = indexs_JA_GA[9]

featuresIndex_lymphography_JA_GA_380iter_run1 = indexs_JA_GA[0]
featuresIndex_lymphography_JA_GA_380iter_run2 = indexs_JA_GA[1]
featuresIndex_lymphography_JA_GA_380iter_run3 = indexs_JA_GA[2]
featuresIndex_lymphography_JA_GA_380iter_run4 = indexs_JA_GA[3]
featuresIndex_lymphography_JA_GA_380iter_run5 = indexs_JA_GA[4]
featuresIndex_lymphography_JA_GA_380iter_run6 = indexs_JA_GA[5]
featuresIndex_lymphography_JA_GA_380iter_run7 = indexs_JA_GA[6]
featuresIndex_lymphography_JA_GA_380iter_run8 = indexs_JA_GA[7]
featuresIndex_lymphography_JA_GA_380iter_run9 = indexs_JA_GA[8]
featuresIndex_lymphography_JA_GA_380iter_run10 = indexs_JA_GA[9]

#ISSA
featuresIndex_lymphography_ISSA_100iter_run1 = indexs_ISSA[0]
featuresIndex_lymphography_ISSA_100iter_run2 = indexs_ISSA[1]
featuresIndex_lymphography_ISSA_100iter_run3 = indexs_ISSA[2]
featuresIndex_lymphography_ISSA_100iter_run4 = indexs_ISSA[3]
featuresIndex_lymphography_ISSA_100iter_run5 = indexs_ISSA[4]
featuresIndex_lymphography_ISSA_100iter_run6 = indexs_ISSA[5]
featuresIndex_lymphography_ISSA_100iter_run7 = indexs_ISSA[6]
featuresIndex_lymphography_ISSA_100iter_run8 = indexs_ISSA[7]
featuresIndex_lymphography_ISSA_100iter_run9 = indexs_ISSA[8]
featuresIndex_lymphography_ISSA_100iter_run10 = indexs_ISSA[9]

featuresIndex_lymphography_ISSA_380iter_run1 = indexs_ISSA[0]
featuresIndex_lymphography_ISSA_380iter_run2 = indexs_ISSA[1]
featuresIndex_lymphography_ISSA_380iter_run3 = indexs_ISSA[2]
featuresIndex_lymphography_ISSA_380iter_run4 = indexs_ISSA[3]
featuresIndex_lymphography_ISSA_380iter_run5 = indexs_ISSA[4]
featuresIndex_lymphography_ISSA_380iter_run6 = indexs_ISSA[5]
featuresIndex_lymphography_ISSA_380iter_run7 = indexs_ISSA[6]
featuresIndex_lymphography_ISSA_380iter_run8 = indexs_ISSA[7]
featuresIndex_lymphography_ISSA_380iter_run9 = indexs_ISSA[8]
featuresIndex_lymphography_ISSA_380iter_run10 = indexs_ISSA[9]

#Jaya
featuresIndex_lymphography_Jaya_100iter_run1 = indexs_Jaya[0]
featuresIndex_lymphography_Jaya_100iter_run2 = indexs_Jaya[1]
featuresIndex_lymphography_Jaya_100iter_run3 = indexs_Jaya[2]
featuresIndex_lymphography_Jaya_100iter_run4 = indexs_Jaya[3]
featuresIndex_lymphography_Jaya_100iter_run5 = indexs_Jaya[4]
featuresIndex_lymphography_Jaya_100iter_run6 = indexs_Jaya[5]
featuresIndex_lymphography_Jaya_100iter_run7 = indexs_Jaya[6]
featuresIndex_lymphography_Jaya_100iter_run8 = indexs_Jaya[7]
featuresIndex_lymphography_Jaya_100iter_run9 = indexs_Jaya[8]
featuresIndex_lymphography_Jaya_100iter_run10 = indexs_Jaya[9]

featuresIndex_lymphography_Jaya_380iter_run1 = indexs_Jaya[0]
featuresIndex_lymphography_Jaya_380iter_run2 = indexs_Jaya[1]
featuresIndex_lymphography_Jaya_380iter_run3 = indexs_Jaya[2]
featuresIndex_lymphography_Jaya_380iter_run4 = indexs_Jaya[3]
featuresIndex_lymphography_Jaya_380iter_run5 = indexs_Jaya[4]
featuresIndex_lymphography_Jaya_380iter_run6 = indexs_Jaya[5]
featuresIndex_lymphography_Jaya_380iter_run7 = indexs_Jaya[6]
featuresIndex_lymphography_Jaya_380iter_run8 = indexs_Jaya[7]
featuresIndex_lymphography_Jaya_380iter_run9 = indexs_Jaya[8]
featuresIndex_lymphography_Jaya_380iter_run10 = indexs_Jaya[9]

#PSO
featuresIndex_lymphography_PSO_100iter_run1 = indexs_PSO[0]
featuresIndex_lymphography_PSO_100iter_run2 = indexs_PSO[1]
featuresIndex_lymphography_PSO_100iter_run3 = indexs_PSO[2]
featuresIndex_lymphography_PSO_100iter_run4 = indexs_PSO[3]
featuresIndex_lymphography_PSO_100iter_run5 = indexs_PSO[4]
featuresIndex_lymphography_PSO_100iter_run6 = indexs_PSO[5]
featuresIndex_lymphography_PSO_100iter_run7 = indexs_PSO[6]
featuresIndex_lymphography_PSO_100iter_run8 = indexs_PSO[7]
featuresIndex_lymphography_PSO_100iter_run9 = indexs_PSO[8]
featuresIndex_lymphography_PSO_100iter_run10 = indexs_PSO[9]

featuresIndex_lymphography_PSO_380iter_run1 = indexs_PSO[0]
featuresIndex_lymphography_PSO_380iter_run2 = indexs_PSO[1]
featuresIndex_lymphography_PSO_380iter_run3 = indexs_PSO[2]
featuresIndex_lymphography_PSO_380iter_run4 = indexs_PSO[3]
featuresIndex_lymphography_PSO_380iter_run5 = indexs_PSO[4]
featuresIndex_lymphography_PSO_380iter_run6 = indexs_PSO[5]
featuresIndex_lymphography_PSO_380iter_run7 = indexs_PSO[6]
featuresIndex_lymphography_PSO_380iter_run8 = indexs_PSO[7]
featuresIndex_lymphography_PSO_380iter_run9 = indexs_PSO[8]
featuresIndex_lymphography_PSO_380iter_run10 = indexs_PSO[9]

#Genetic
featuresIndex_lymphography_Genetic_100iter_run1 = indexs_Genetic[0]
featuresIndex_lymphography_Genetic_100iter_run2 = indexs_Genetic[1]
featuresIndex_lymphography_Genetic_100iter_run3 = indexs_Genetic[2]
featuresIndex_lymphography_Genetic_100iter_run4 = indexs_Genetic[3]
featuresIndex_lymphography_Genetic_100iter_run5 = indexs_Genetic[4]
featuresIndex_lymphography_Genetic_100iter_run6 = indexs_Genetic[5]
featuresIndex_lymphography_Genetic_100iter_run7 = indexs_Genetic[6]
featuresIndex_lymphography_Genetic_100iter_run8 = indexs_Genetic[7]
featuresIndex_lymphography_Genetic_100iter_run9 = indexs_Genetic[8]
featuresIndex_lymphography_Genetic_100iter_run10 = indexs_Genetic[9]

featuresIndex_lymphography_Genetic_380iter_run1 = indexs_Genetic[0]
featuresIndex_lymphography_Genetic_380iter_run2 = indexs_Genetic[1]
featuresIndex_lymphography_Genetic_380iter_run3 = indexs_Genetic[2]
featuresIndex_lymphography_Genetic_380iter_run4 = indexs_Genetic[3]
featuresIndex_lymphography_Genetic_380iter_run5 = indexs_Genetic[4]
featuresIndex_lymphography_Genetic_380iter_run6 = indexs_Genetic[5]
featuresIndex_lymphography_Genetic_380iter_run7 = indexs_Genetic[6]
featuresIndex_lymphography_Genetic_380iter_run8 = indexs_Genetic[7]
featuresIndex_lymphography_Genetic_380iter_run9 = indexs_Genetic[8]
featuresIndex_lymphography_Genetic_380iter_run10 = indexs_Genetic[9]

#MGFPA
featuresIndex_lymphography_MGFPA_100iter_run1 = indexs_MGFPA[0]
featuresIndex_lymphography_MGFPA_100iter_run2 = indexs_MGFPA[1]
featuresIndex_lymphography_MGFPA_100iter_run3 = indexs_MGFPA[2]
featuresIndex_lymphography_MGFPA_100iter_run4 = indexs_MGFPA[3]
featuresIndex_lymphography_MGFPA_100iter_run5 = indexs_MGFPA[4]
featuresIndex_lymphography_MGFPA_100iter_run6 = indexs_MGFPA[5]
featuresIndex_lymphography_MGFPA_100iter_run7 = indexs_MGFPA[6]
featuresIndex_lymphography_MGFPA_100iter_run8 = indexs_MGFPA[7]
featuresIndex_lymphography_MGFPA_100iter_run9 = indexs_MGFPA[8]
featuresIndex_lymphography_MGFPA_100iter_run10 = indexs_MGFPA[9]

featuresIndex_lymphography_MGFPA_380iter_run1 = indexs_MGFPA[0]
featuresIndex_lymphography_MGFPA_380iter_run2 = indexs_MGFPA[1]
featuresIndex_lymphography_MGFPA_380iter_run3 = indexs_MGFPA[2]
featuresIndex_lymphography_MGFPA_380iter_run4 = indexs_MGFPA[3]
featuresIndex_lymphography_MGFPA_380iter_run5 = indexs_MGFPA[4]
featuresIndex_lymphography_MGFPA_380iter_run6 = indexs_MGFPA[5]
featuresIndex_lymphography_MGFPA_380iter_run7 = indexs_MGFPA[6]
featuresIndex_lymphography_MGFPA_380iter_run8 = indexs_MGFPA[7]
featuresIndex_lymphography_MGFPA_380iter_run9 = indexs_MGFPA[8]
featuresIndex_lymphography_MGFPA_380iter_run10 = indexs_MGFPA[9]

# %% [markdown]
# # 100 Iteration (10 Individual Runs)

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_JA_GA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_lymphography_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_lymphography_100iter.to_csv("./cv10_results_JA_GA_lymphography_100iter.csv")
cv10_results_JA_GA_lymphography_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7333333333333333  Precision:  0.37236842105263157  Recall:  0.366421568627451  F1-Score:  0.36742424242424243
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7333333333333333  Precision:  0.49404761904761907  Recall:  0.5130718954248367  F1-Score:  0.49615975422427033
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8333333333333334  Precision:  0.5505279034690799  Recall:  0.5718954248366014  F1-Score:  0.5607843137254902
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7666666666666667  Precision:  0.8349358974358975  Recall:  0.8382352941176471  F1-Score:  0.8359595959595959
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7333333333333333  Precision:  0.49404761904761907  Recall:  0.5130718954248367  F1-Score:  0.49615975422427033
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_ISSA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISSA_lymphography_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_lymphography_100iter.to_csv("./cv10_results_ISSA_lymphography_100iter.csv")
cv10_results_ISSA_lymphography_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7333333333333333  Precision:  0.49404761904761907  Recall:  0.5130718954248367  F1-Score:  0.49615975422427033
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6333333333333333  Precision:  0.4349206349206349  Recall:  0.43790849673202614  F1-Score:  0.4342948717948718
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.6666666666666666  Precision:  0.46140350877192987  Recall:  0.4493464052287582  F1-Score:  0.45286195286195285
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7333333333333333  Precision:  0.5079365079365079  Recall:  0.5130718954248367  F1-Score:  0.5049780963759458
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7333333333333333  Precision:  0.49404761904761907  Recall:  0.5130718954248367  F1-Score:  0.49615975422427033
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_Genetic_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_lymphography_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_lymphography_100iter.to_csv("./cv10_results_Genetic_lymphography_100iter.csv")
cv10_results_Genetic_lymphography_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7666666666666667  Precision:  0.5052790346907994  Recall:  0.5245098039215687  F1-Score:  0.5145098039215686
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7666666666666667  Precision:  0.5245098039215687  Recall:  0.5245098039215687  F1-Score:  0.5245098039215687
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7333333333333333  Precision:  0.4856711915535445  Recall:  0.5049019607843137  F1-Score:  0.4949019607843137
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8  Precision:  0.548076923076923  Recall:  0.5522875816993463  F1-Score:  0.5494949494949495
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.6666666666666666  Precision:  0.44047619047619047  Recall:  0.45751633986928103  F1-Score:  0.4475524475524475
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_Jaya_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_lymphography_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_lymphography_100iter.to_csv("./cv10_results_Jaya_lymphography_100iter.csv")
cv10_results_Jaya_lymphography_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.6  Precision:  0.39999999999999997  Recall:  0.41830065359477125  F1-Score:  0.40586419753086417
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7  Precision:  0.4781297134238311  Recall:  0.4934640522875817  F1-Score:  0.47432950191570883
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7  Precision:  0.4781297134238311  Recall:  0.4934640522875817  F1-Score:  0.47432950191570883
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7333333333333333  Precision:  0.48148148148148145  Recall:  0.49673202614379086  F1-Score:  0.4888888888888889
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7  Precision:  0.47712418300653586  Recall:  0.47712418300653586  F1-Score:  0.477124183006536
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_PSO_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_lymphography_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_lymphography_100iter.to_csv("./cv10_results_PSO_lymphography_100iter.csv")
cv10_results_PSO_lymphography_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7333333333333333  Precision:  0.4973544973544974  Recall:  0.488562091503268  F1-Score:  0.4853801169590643
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6333333333333333  Precision:  0.40988835725677825  Recall:  0.4215686274509804  F1-Score:  0.4146537842190016
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8  Precision:  0.5277777777777778  Recall:  0.5441176470588235  F1-Score:  0.5357142857142857
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6666666666666666  Precision:  0.4333333333333333  Recall:  0.4411764705882353  F1-Score:  0.434070434070434
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7  Precision:  0.47727272727272724  Recall:  0.46078431372549017  F1-Score:  0.4564102564102564
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_MGFPA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_lymphography_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_lymphography_100iter.to_csv("./cv10_results_MGFPA_lymphography_100iter.csv")
cv10_results_MGFPA_lymphography_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7333333333333333  Precision:  0.4856711915535445  Recall:  0.5049019607843137  F1-Score:  0.4949019607843137
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7333333333333333  Precision:  0.5016025641025641  Recall:  0.5049019607843137  F1-Score:  0.5026262626262626
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7333333333333333  Precision:  0.5016025641025641  Recall:  0.5049019607843137  F1-Score:  0.5026262626262626
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7333333333333333  Precision:  0.49404761904761907  Recall:  0.5130718954248367  F1-Score:  0.49615975422427033
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7  Precision:  0.4781297134238311  Recall:  0.4934640522875817  F1-Score:  0.47432950191570883
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# # 380 Iteration

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_JA_GA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")


av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_lymphography_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_lymphography_380iter.to_csv("./cv10_results_JA_GA_lymphography_380iter.csv")
cv10_results_JA_GA_lymphography_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7  Precision:  0.4603174603174603  Recall:  0.46078431372549017  F1-Score:  0.45363408521303256
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7666666666666667  Precision:  0.5055821371610846  Recall:  0.5163398692810457  F1-Score:  0.5096618357487922
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7666666666666667  Precision:  0.5055821371610846  Recall:  0.5163398692810457  F1-Score:  0.5096618357487922
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6333333333333333  Precision:  0.40988835725677825  Recall:  0.4215686274509804  F1-Score:  0.4146537842190016
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7666666666666667  Precision:  0.5055821371610846  Recall:  0.5163398692810457  F1-Score:  0.5096618357487922
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# #### ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_ISSA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISSA_lymphography_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_lymphography_380iter.to_csv("./cv10_results_ISSA_lymphography_380iter.csv")
cv10_results_ISSA_lymphography_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7666666666666667  Precision:  0.5111111111111111  Recall:  0.5326797385620915  F1-Score:  0.5177469135802469
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7  Precision:  0.4666666666666666  Recall:  0.4852941176470589  F1-Score:  0.47222222222222215
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7  Precision:  0.4666666666666666  Recall:  0.468954248366013  F1-Score:  0.46437346437346444
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7666666666666667  Precision:  0.5111111111111111  Recall:  0.5326797385620915  F1-Score:  0.5177469135802469
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7666666666666667  Precision:  0.5111111111111111  Recall:  0.5326797385620915  F1-Score:  0.5177469135802469
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_Genetic_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_lymphography_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_lymphography_380iter.to_csv("./cv10_results_Genetic_lymphography_380iter.csv")
cv10_results_Genetic_lymphography_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.6333333333333333  Precision:  0.40988835725677825  Recall:  0.4215686274509804  F1-Score:  0.4146537842190016
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7333333333333333  Precision:  0.5092592592592592  Recall:  0.488562091503268  F1-Score:  0.4924924924924925
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.6666666666666666  Precision:  0.44019138755980863  Recall:  0.4493464052287582  F1-Score:  0.44363929146537845
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.7  Precision:  0.47894736842105257  Recall:  0.468954248366013  F1-Score:  0.47138047138047146
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.6666666666666666  Precision:  0.4333333333333333  Recall:  0.4411764705882353  F1-Score:  0.434070434070434
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_Jaya_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_lymphography_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_lymphography_380iter.to_csv("./cv10_results_Jaya_lymphography_380iter.csv")
cv10_results_Jaya_lymphography_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7333333333333333  Precision:  0.4851190476190476  Recall:  0.5049019607843137  F1-Score:  0.49339549339549343
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6333333333333333  Precision:  0.40988835725677825  Recall:  0.4215686274509804  F1-Score:  0.4146537842190016
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7  Precision:  0.4577352472089314  Recall:  0.468954248366013  F1-Score:  0.46215780998389694
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6333333333333333  Precision:  0.40988835725677825  Recall:  0.4215686274509804  F1-Score:  0.4146537842190016
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7666666666666667  Precision:  0.5166666666666667  Recall:  0.5163398692810457  F1-Score:  0.5126945126945127
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_PSO_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_lymphography_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_lymphography_380iter.to_csv("./cv10_results_PSO_lymphography_380iter.csv")
cv10_results_PSO_lymphography_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7333333333333333  Precision:  0.4973544973544974  Recall:  0.488562091503268  F1-Score:  0.4853801169590643
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.6333333333333333  Precision:  0.40988835725677825  Recall:  0.4215686274509804  F1-Score:  0.4146537842190016
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8  Precision:  0.5277777777777778  Recall:  0.5441176470588235  F1-Score:  0.5357142857142857
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6666666666666666  Precision:  0.4333333333333333  Recall:  0.4411764705882353  F1-Score:  0.434070434070434
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.7  Precision:  0.47727272727272724  Recall:  0.46078431372549017  F1-Score:  0.4564102564102564
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_lymphography_MGFPA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_lymphography[:, var_value_indexes]
    xtest = features_test_lymphography[:, var_value_indexes]
    xtrain = xtrain.astype('float32')
    y_train = y_train.astype('float32')
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_lymphography_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_lymphography_380iter.to_csv("./cv10_results_MGFPA_lymphography_380iter.csv")
cv10_results_MGFPA_lymphography_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7333333333333333  Precision:  0.4856711915535445  Recall:  0.5049019607843137  F1-Score:  0.4949019607843137
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.7  Precision:  0.47712418300653586  Recall:  0.47712418300653586  F1-Score:  0.477124183006536
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.7  Precision:  0.47712418300653586  Recall:  0.47712418300653586  F1-Score:  0.477124183006536
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.6333333333333333  Precision:  0.43288084464555054  Recall:  0.44607843137254904  F1-Score:  0.4291187739463602
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.6333333333333333  Precision:  0.43288084464555054  Recall:  0.44607843137254904  F1-Score:  0.4291187739463602
# ---------------------------------------------------------
# Run:  6
# ...
