# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
from sklearn.model_selection import train_test_split
#from sklearn.svm import SVC
from cuml.svm import SVC, SVR
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import seaborn as sns
from sklearn.tree import plot_tree
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings("ignore")


from sklearn import set_config 

set_config(display="diagram")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
#Genetic
df = pd.read_csv("/kaggle/input/benchmarkjagen/Hepatitis/Results_Genetic.csv")
df.head(11)
indexs_Genetic = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Genetic.append(np.array(numbers))
        
#ISCA        
df = pd.read_csv("/kaggle/input/benchmarkjagen/Hepatitis/Results_ISCA.csv")
df.head(11)
indexs_ISCA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISCA.append(np.array(numbers))

#ISSA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Hepatitis/Results_ISSA.csv")
df.head(11)
indexs_ISSA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_ISSA.append(np.array(numbers))
        
#JA_GA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Hepatitis/Results_JA+GA.csv")
df.head(11)
indexs_JA_GA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_JA_GA.append(np.array(numbers))

#Jaya
df = pd.read_csv("/kaggle/input/benchmarkjagen/Hepatitis/Results_Jaya.csv")
df.head(11)
indexs_Jaya = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_Jaya.append(np.array(numbers))

#MGFPA
df = pd.read_csv("/kaggle/input/benchmarkjagen/Hepatitis/Results_MGFPA.csv")
df.head(11)
indexs_MGFPA = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_MGFPA.append(np.array(numbers))

#PSO
df = pd.read_csv("/kaggle/input/benchmarkjagen/Hepatitis/Results_PSO.csv")
df.head(11)
indexs_PSO = []
# Iterate over the lists in the column
for lst in df['Selected index 100']:    
        numbers = lst.strip('[]').split()
        numbers = [int(num) for num in numbers]
        indexs_PSO.append(np.array(numbers))

# %%
#Original
features_test_Hepatitis = np.load('/kaggle/input/benchmarkjagen/Hepatitis/xtest.npy')
y_test = np.load("/kaggle/input/benchmarkjagen/Hepatitis/ytest.npy")
features_train_Hepatitis = np.load('/kaggle/input/benchmarkjagen/Hepatitis/xtrain.npy')
y_train = np.load("/kaggle/input/benchmarkjagen/Hepatitis/ytrain.npy")
#JA + GA (Jaya + Genetic)
featuresIndex_Hepatitis_JA_GA_100iter_run1 = indexs_JA_GA[0]
featuresIndex_Hepatitis_JA_GA_100iter_run2 = indexs_JA_GA[1]
featuresIndex_Hepatitis_JA_GA_100iter_run3 = indexs_JA_GA[2]
featuresIndex_Hepatitis_JA_GA_100iter_run4 = indexs_JA_GA[3]
featuresIndex_Hepatitis_JA_GA_100iter_run5 = indexs_JA_GA[4]
featuresIndex_Hepatitis_JA_GA_100iter_run6 = indexs_JA_GA[5]
featuresIndex_Hepatitis_JA_GA_100iter_run7 = indexs_JA_GA[6]
featuresIndex_Hepatitis_JA_GA_100iter_run8 = indexs_JA_GA[7]
featuresIndex_Hepatitis_JA_GA_100iter_run9 = indexs_JA_GA[8]
featuresIndex_Hepatitis_JA_GA_100iter_run10 = indexs_JA_GA[9]

featuresIndex_Hepatitis_JA_GA_380iter_run1 = indexs_JA_GA[0]
featuresIndex_Hepatitis_JA_GA_380iter_run2 = indexs_JA_GA[1]
featuresIndex_Hepatitis_JA_GA_380iter_run3 = indexs_JA_GA[2]
featuresIndex_Hepatitis_JA_GA_380iter_run4 = indexs_JA_GA[3]
featuresIndex_Hepatitis_JA_GA_380iter_run5 = indexs_JA_GA[4]
featuresIndex_Hepatitis_JA_GA_380iter_run6 = indexs_JA_GA[5]
featuresIndex_Hepatitis_JA_GA_380iter_run7 = indexs_JA_GA[6]
featuresIndex_Hepatitis_JA_GA_380iter_run8 = indexs_JA_GA[7]
featuresIndex_Hepatitis_JA_GA_380iter_run9 = indexs_JA_GA[8]
featuresIndex_Hepatitis_JA_GA_380iter_run10 = indexs_JA_GA[9]

#ISSA
featuresIndex_Hepatitis_ISSA_100iter_run1 = indexs_ISSA[0]
featuresIndex_Hepatitis_ISSA_100iter_run2 = indexs_ISSA[1]
featuresIndex_Hepatitis_ISSA_100iter_run3 = indexs_ISSA[2]
featuresIndex_Hepatitis_ISSA_100iter_run4 = indexs_ISSA[3]
featuresIndex_Hepatitis_ISSA_100iter_run5 = indexs_ISSA[4]
featuresIndex_Hepatitis_ISSA_100iter_run6 = indexs_ISSA[5]
featuresIndex_Hepatitis_ISSA_100iter_run7 = indexs_ISSA[6]
featuresIndex_Hepatitis_ISSA_100iter_run8 = indexs_ISSA[7]
featuresIndex_Hepatitis_ISSA_100iter_run9 = indexs_ISSA[8]
featuresIndex_Hepatitis_ISSA_100iter_run10 = indexs_ISSA[9]

featuresIndex_Hepatitis_ISSA_380iter_run1 = indexs_ISSA[0]
featuresIndex_Hepatitis_ISSA_380iter_run2 = indexs_ISSA[1]
featuresIndex_Hepatitis_ISSA_380iter_run3 = indexs_ISSA[2]
featuresIndex_Hepatitis_ISSA_380iter_run4 = indexs_ISSA[3]
featuresIndex_Hepatitis_ISSA_380iter_run5 = indexs_ISSA[4]
featuresIndex_Hepatitis_ISSA_380iter_run6 = indexs_ISSA[5]
featuresIndex_Hepatitis_ISSA_380iter_run7 = indexs_ISSA[6]
featuresIndex_Hepatitis_ISSA_380iter_run8 = indexs_ISSA[7]
featuresIndex_Hepatitis_ISSA_380iter_run9 = indexs_ISSA[8]
featuresIndex_Hepatitis_ISSA_380iter_run10 = indexs_ISSA[9]

#Jaya
featuresIndex_Hepatitis_Jaya_100iter_run1 = indexs_Jaya[0]
featuresIndex_Hepatitis_Jaya_100iter_run2 = indexs_Jaya[1]
featuresIndex_Hepatitis_Jaya_100iter_run3 = indexs_Jaya[2]
featuresIndex_Hepatitis_Jaya_100iter_run4 = indexs_Jaya[3]
featuresIndex_Hepatitis_Jaya_100iter_run5 = indexs_Jaya[4]
featuresIndex_Hepatitis_Jaya_100iter_run6 = indexs_Jaya[5]
featuresIndex_Hepatitis_Jaya_100iter_run7 = indexs_Jaya[6]
featuresIndex_Hepatitis_Jaya_100iter_run8 = indexs_Jaya[7]
featuresIndex_Hepatitis_Jaya_100iter_run9 = indexs_Jaya[8]
featuresIndex_Hepatitis_Jaya_100iter_run10 = indexs_Jaya[9]

featuresIndex_Hepatitis_Jaya_380iter_run1 = indexs_Jaya[0]
featuresIndex_Hepatitis_Jaya_380iter_run2 = indexs_Jaya[1]
featuresIndex_Hepatitis_Jaya_380iter_run3 = indexs_Jaya[2]
featuresIndex_Hepatitis_Jaya_380iter_run4 = indexs_Jaya[3]
featuresIndex_Hepatitis_Jaya_380iter_run5 = indexs_Jaya[4]
featuresIndex_Hepatitis_Jaya_380iter_run6 = indexs_Jaya[5]
featuresIndex_Hepatitis_Jaya_380iter_run7 = indexs_Jaya[6]
featuresIndex_Hepatitis_Jaya_380iter_run8 = indexs_Jaya[7]
featuresIndex_Hepatitis_Jaya_380iter_run9 = indexs_Jaya[8]
featuresIndex_Hepatitis_Jaya_380iter_run10 = indexs_Jaya[9]

#PSO
featuresIndex_Hepatitis_PSO_100iter_run1 = indexs_PSO[0]
featuresIndex_Hepatitis_PSO_100iter_run2 = indexs_PSO[1]
featuresIndex_Hepatitis_PSO_100iter_run3 = indexs_PSO[2]
featuresIndex_Hepatitis_PSO_100iter_run4 = indexs_PSO[3]
featuresIndex_Hepatitis_PSO_100iter_run5 = indexs_PSO[4]
featuresIndex_Hepatitis_PSO_100iter_run6 = indexs_PSO[5]
featuresIndex_Hepatitis_PSO_100iter_run7 = indexs_PSO[6]
featuresIndex_Hepatitis_PSO_100iter_run8 = indexs_PSO[7]
featuresIndex_Hepatitis_PSO_100iter_run9 = indexs_PSO[8]
featuresIndex_Hepatitis_PSO_100iter_run10 = indexs_PSO[9]

featuresIndex_Hepatitis_PSO_380iter_run1 = indexs_PSO[0]
featuresIndex_Hepatitis_PSO_380iter_run2 = indexs_PSO[1]
featuresIndex_Hepatitis_PSO_380iter_run3 = indexs_PSO[2]
featuresIndex_Hepatitis_PSO_380iter_run4 = indexs_PSO[3]
featuresIndex_Hepatitis_PSO_380iter_run5 = indexs_PSO[4]
featuresIndex_Hepatitis_PSO_380iter_run6 = indexs_PSO[5]
featuresIndex_Hepatitis_PSO_380iter_run7 = indexs_PSO[6]
featuresIndex_Hepatitis_PSO_380iter_run8 = indexs_PSO[7]
featuresIndex_Hepatitis_PSO_380iter_run9 = indexs_PSO[8]
featuresIndex_Hepatitis_PSO_380iter_run10 = indexs_PSO[9]

#MGFPA
featuresIndex_Hepatitis_MGFPA_100iter_run1 = indexs_MGFPA[0]
featuresIndex_Hepatitis_MGFPA_100iter_run2 = indexs_MGFPA[1]
featuresIndex_Hepatitis_MGFPA_100iter_run3 = indexs_MGFPA[2]
featuresIndex_Hepatitis_MGFPA_100iter_run4 = indexs_MGFPA[3]
featuresIndex_Hepatitis_MGFPA_100iter_run5 = indexs_MGFPA[4]
featuresIndex_Hepatitis_MGFPA_100iter_run6 = indexs_MGFPA[5]
featuresIndex_Hepatitis_MGFPA_100iter_run7 = indexs_MGFPA[6]
featuresIndex_Hepatitis_MGFPA_100iter_run8 = indexs_MGFPA[7]
featuresIndex_Hepatitis_MGFPA_100iter_run9 = indexs_MGFPA[8]
featuresIndex_Hepatitis_MGFPA_100iter_run10 = indexs_MGFPA[9]

featuresIndex_Hepatitis_MGFPA_380iter_run1 = indexs_MGFPA[0]
featuresIndex_Hepatitis_MGFPA_380iter_run2 = indexs_MGFPA[1]
featuresIndex_Hepatitis_MGFPA_380iter_run3 = indexs_MGFPA[2]
featuresIndex_Hepatitis_MGFPA_380iter_run4 = indexs_MGFPA[3]
featuresIndex_Hepatitis_MGFPA_380iter_run5 = indexs_MGFPA[4]
featuresIndex_Hepatitis_MGFPA_380iter_run6 = indexs_MGFPA[5]
featuresIndex_Hepatitis_MGFPA_380iter_run7 = indexs_MGFPA[6]
featuresIndex_Hepatitis_MGFPA_380iter_run8 = indexs_MGFPA[7]
featuresIndex_Hepatitis_MGFPA_380iter_run9 = indexs_MGFPA[8]
featuresIndex_Hepatitis_MGFPA_380iter_run10 = indexs_MGFPA[9]

#Genetic
featuresIndex_Hepatitis_Genetic_100iter_run1 = indexs_Genetic[0]
featuresIndex_Hepatitis_Genetic_100iter_run2 = indexs_Genetic[1]
featuresIndex_Hepatitis_Genetic_100iter_run3 = indexs_Genetic[2]
featuresIndex_Hepatitis_Genetic_100iter_run4 = indexs_Genetic[3]
featuresIndex_Hepatitis_Genetic_100iter_run5 = indexs_Genetic[4]
featuresIndex_Hepatitis_Genetic_100iter_run6 = indexs_Genetic[5]
featuresIndex_Hepatitis_Genetic_100iter_run7 = indexs_Genetic[6]
featuresIndex_Hepatitis_Genetic_100iter_run8 = indexs_Genetic[7]
featuresIndex_Hepatitis_Genetic_100iter_run9 = indexs_Genetic[8]
featuresIndex_Hepatitis_Genetic_100iter_run10 = indexs_Genetic[9]

featuresIndex_Hepatitis_Genetic_380iter_run1 = indexs_Genetic[0]
featuresIndex_Hepatitis_Genetic_380iter_run2 = indexs_Genetic[1]
featuresIndex_Hepatitis_Genetic_380iter_run3 = indexs_Genetic[2]
featuresIndex_Hepatitis_Genetic_380iter_run4 = indexs_Genetic[3]
featuresIndex_Hepatitis_Genetic_380iter_run5 = indexs_Genetic[4]
featuresIndex_Hepatitis_Genetic_380iter_run6 = indexs_Genetic[5]
featuresIndex_Hepatitis_Genetic_380iter_run7 = indexs_Genetic[6]
featuresIndex_Hepatitis_Genetic_380iter_run8 = indexs_Genetic[7]
featuresIndex_Hepatitis_Genetic_380iter_run9 = indexs_Genetic[8]
featuresIndex_Hepatitis_Genetic_380iter_run10 = indexs_Genetic[9]

#ISCA
featuresIndex_Hepatitis_ISCA_100iter_run1 = indexs_ISCA[0]
featuresIndex_Hepatitis_ISCA_100iter_run2 = indexs_ISCA[1]
featuresIndex_Hepatitis_ISCA_100iter_run3 = indexs_ISCA[2]
featuresIndex_Hepatitis_ISCA_100iter_run4 = indexs_ISCA[3]
featuresIndex_Hepatitis_ISCA_100iter_run5 = indexs_ISCA[4]
featuresIndex_Hepatitis_ISCA_100iter_run6 = indexs_ISCA[5]
featuresIndex_Hepatitis_ISCA_100iter_run7 = indexs_ISCA[6]
featuresIndex_Hepatitis_ISCA_100iter_run8 = indexs_ISCA[7]
featuresIndex_Hepatitis_ISCA_100iter_run9 = indexs_ISCA[8]
featuresIndex_Hepatitis_ISCA_100iter_run10 = indexs_ISCA[9]

featuresIndex_Hepatitis_ISCA_380iter_run1 = indexs_ISCA[0]
featuresIndex_Hepatitis_ISCA_380iter_run2 = indexs_ISCA[1]
featuresIndex_Hepatitis_ISCA_380iter_run3 = indexs_ISCA[2]
featuresIndex_Hepatitis_ISCA_380iter_run4 = indexs_ISCA[3]
featuresIndex_Hepatitis_ISCA_380iter_run5 = indexs_ISCA[4]
featuresIndex_Hepatitis_ISCA_380iter_run6 = indexs_ISCA[5]
featuresIndex_Hepatitis_ISCA_380iter_run7 = indexs_ISCA[6]
featuresIndex_Hepatitis_ISCA_380iter_run8 = indexs_ISCA[7]
featuresIndex_Hepatitis_ISCA_380iter_run9 = indexs_ISCA[8]
featuresIndex_Hepatitis_ISCA_380iter_run10 = indexs_ISCA[9]

# %% [markdown]
# # 100 Iteration (10 Individual Runs)

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_JA_GA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Hepatitis_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Hepatitis_100iter.to_csv("./cv10_results_JA_GA_Hepatitis_100iter.csv")
cv10_results_JA_GA_Hepatitis_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_ISSA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISSA_Hepatitis_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Hepatitis_100iter.to_csv("./cv10_results_ISSA_Hepatitis_100iter.csv")
cv10_results_ISSA_Hepatitis_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.7586206896551724  Precision:  0.6014492753623188  Recall:  0.6166666666666667  F1-Score:  0.6073500967117988
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_ISCA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1, " AUC: ", av_auc)
cv10_results_ISCA_Hepatitis_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Hepatitis_100iter.to_csv("./cv10_results_ISCA_Hepatitis_100iter.csv")
cv10_results_ISCA_Hepatitis_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_Genetic_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Hepatitis_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Hepatitis_100iter.to_csv("./cv10_results_Genetic_Hepatitis_100iter.csv")
cv10_results_Genetic_Hepatitis_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8275862068965517  Precision:  0.69  Recall:  0.6583333333333333  F1-Score:  0.671201814058957
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_Jaya_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Hepatitis_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Hepatitis_100iter.to_csv("./cv10_results_Jaya_Hepatitis_100iter.csv")
cv10_results_Jaya_Hepatitis_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8275862068965517  Precision:  0.7065217391304348  Recall:  0.7375  F1-Score:  0.7195357833655706
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_PSO_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Hepatitis_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Hepatitis_100iter.to_csv("./cv10_results_PSO_Hepatitis_100iter.csv")
cv10_results_PSO_Hepatitis_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8275862068965517  Precision:  0.6759259259259259  Recall:  0.5791666666666667  F1-Score:  0.5938375350140057
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_MGFPA_100iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Hepatitis_100iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Hepatitis_100iter.to_csv("./cv10_results_MGFPA_Hepatitis_100iter.csv")
cv10_results_MGFPA_Hepatitis_100iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# # 380 Iteration

# %% [markdown]
# ## Jaya + Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_JA_GA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")


av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_JA_GA_Hepatitis_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_JA_GA_Hepatitis_380iter.to_csv("./cv10_results_JA_GA_Hepatitis_380iter.csv")
cv10_results_JA_GA_Hepatitis_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# #### ISSA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_ISSA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISSA_Hepatitis_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISSA_Hepatitis_380iter.to_csv("./cv10_results_ISSA_Hepatitis_380iter.csv")
cv10_results_ISSA_Hepatitis_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## ISCA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_ISCA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_ISCA_Hepatitis_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_ISCA_Hepatitis_380iter.to_csv("./cv10_results_ISCA_Hepatitis_380iter.csv")
cv10_results_ISCA_Hepatitis_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8275862068965517  Precision:  0.69  Recall:  0.6583333333333333  F1-Score:  0.671201814058957
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Genetic

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_Genetic_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Genetic_Hepatitis_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Genetic_Hepatitis_380iter.to_csv("./cv10_results_Genetic_Hepatitis_380iter.csv")
cv10_results_Genetic_Hepatitis_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8275862068965517  Precision:  0.69  Recall:  0.6583333333333333  F1-Score:  0.671201814058957
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## Jaya

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_Jaya_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_Jaya_Hepatitis_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_Jaya_Hepatitis_380iter.to_csv("./cv10_results_Jaya_Hepatitis_380iter.csv")
cv10_results_Jaya_Hepatitis_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8275862068965517  Precision:  0.7065217391304348  Recall:  0.7375  F1-Score:  0.7195357833655706
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## PSO

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_PSO_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_PSO_Hepatitis_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_PSO_Hepatitis_380iter.to_csv("./cv10_results_PSO_Hepatitis_380iter.csv")
cv10_results_PSO_Hepatitis_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8275862068965517  Precision:  0.6759259259259259  Recall:  0.5791666666666667  F1-Score:  0.5938375350140057
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...

# %% [markdown]
# ## MGFPA

# %%
tprs = []
aucs = []
fprs = []
# Define per-fold score containers <-- these are new
accuracy_per_run = []
precision_per_run = []
recall_per_run = []
f1score_per_run = []
N_run = 0
for i in range(1, 11):
    var_indexes = f"featuresIndex_Hepatitis_MGFPA_380iter_run{i}"
    var_value_indexes = locals()[var_indexes]
    xtrain = features_train_Hepatitis[:, var_value_indexes]
    xtest = features_test_Hepatitis[:, var_value_indexes]
    clf = None
    clf = SVC(kernel='rbf', random_state=0)
    clf.fit(xtrain, y_train)
    preds = clf.predict(xtest)
    precision = precision_score(y_test, preds, average='macro')
    recall = recall_score(y_test, preds, average='macro')
    accuracy = accuracy_score(y_test, preds)
    f1 = f1_score(y_test, preds,  average='macro')
    accuracy_per_run.append(accuracy)
    precision_per_run.append(precision)
    recall_per_run.append(recall)
    f1score_per_run.append(f1)
    N_run += 1
    print("Run: ", N_run)
    print(" Accuracy: ", accuracy, " Precision: ", precision, " Recall: ", recall, " F1-Score: ", f1)
    confusionM = confusion_matrix(preds, y_test)
    print("---------------------------------------------------------")

av_acc = sum(accuracy_per_run)/ len(accuracy_per_run)
av_pre = sum(precision_per_run)/ len(accuracy_per_run)
av_rec = sum(recall_per_run)/ len(accuracy_per_run)
av_f1 = sum(f1score_per_run)/ len(accuracy_per_run)
av_auc = sum(aucs) / len(accuracy_per_run)
print("Average: ")
print(" Accuracy: ", av_acc, " Precision: ", av_pre, " Recall: ", av_rec, " F1-Score: ", av_f1)
cv10_results_MGFPA_Hepatitis_380iter = pd.DataFrame(data={"Accuracy": accuracy_per_run, "Precision": precision_per_run, "Recall": recall_per_run, "F1-Score": f1score_per_run})
cv10_results_MGFPA_Hepatitis_380iter.to_csv("./cv10_results_MGFPA_Hepatitis_380iter.csv")
cv10_results_MGFPA_Hepatitis_380iter.head()
# Out:
# Run:  1
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  2
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  3
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  4
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  5
#  Accuracy:  0.8620689655172413  Precision:  0.7583333333333333  Recall:  0.7583333333333333  F1-Score:  0.7583333333333333
# ---------------------------------------------------------
# Run:  6
# ...
